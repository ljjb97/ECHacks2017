# %%
import os
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("C:/Users/Santhoshkumar/Desktop/Abhi/pbp-2016.csv")
data = data.drop(['Minute','Second','IsTwoPointConversionSuccessful','RushDirection','YardLineFixed','YardLineDirection', 'IsPenaltyAccepted', 'PenaltyTeam','PenaltyType','PenaltyYards'], axis =1)
data = data.drop(['IsFumble','IsInterception','IsMeasurement','Challenger','IsChallengeReversed','PassType','IsTouchdown','SeriesFirstDown','Unnamed: 10','ToGo','YardLine'], axis = 1)
data = data.drop(['NextScore','Description','Unnamed: 17', 'SeasonYear','IsIncomplete','IsChallenge'], axis = 1)
data = data.drop(['Unnamed: 12','Unnamed: 16','TeamWin','GameId'],axis = 1)
data = data.dropna()
#cut all the unwanted data, cleaning - abhi
#ata = pd.concat([data, pd.get_dummies(data['Formation'])], axis =1)
#ata = data.drop(['Formation'], axis = 1)
data = pd.concat([data, pd.get_dummies(data['PlayType'])], axis =1)
data = data.drop(['PlayType'], axis = 1)
column_a = data['Yards']
column_a
b = []

# print (data.groupby(['Formation','Yards']).groups)
data
# Out:
#          GameDate  Quarter OffenseTeam DefenseTeam  Down  Yards  \
# 6      2016-09-11        2         HOU         CHI     0      0
# 8      2016-09-11        3         HOU         CHI     1      0
# 15     2016-09-11        2          NO         OAK     2      6
# 16     2016-09-11        2          NO         OAK     3      0
# 17     2016-09-11        2          NO         OAK     4      0
# 18     2016-09-11        2          NO         OAK     4      0
# 19     2016-09-11        2         OAK          NO     1      9
# 21     2016-09-11        3          NO         OAK     4      0
# 22     2016-09-11        3          NO         OAK     2      1
# 23     2016-09-11        4         OAK          NO     0      0
# 24     2016-09-11        4         OAK          NO     1      1
# 27     2016-09-11        2         CIN         NYJ     2      4
# 30     2016-09-11        1         CLE         PHI     0      0
# 31     2016-09-11        1         PHI         CLE     1      6
# 32     2016-09-11        1         PHI         CLE     2      1
# 33     2016-09-11        1         PHI         CLE     3      0
# 34     2016-09-11        1         PHI         CLE     1      0
# 35     2016-09-11        1         PHI         CLE     1      5
# 36     2016-09-11        3         PHI         CLE     0      0
# 37     2016-09-11        3         CLE         PHI     1      0
# 39     2016-09-11        1         MIN         TEN     2      1
# 40     2016-09-11        2         MIN         TEN     3      6
# 41     2016-09-11        2         MIN         TEN     1      2
# 42     2016-09-11        2         TEN         MIN     3     16
# 45     2016-09-11        3         MIN         TEN     1      2
# 46     2016-09-11        3         MIN         TEN     1      3
# 47     2016-11-27        2         OAK         CAR     2      0
# 48     2016-11-27        2         OAK         CAR     3      0
# 49     2016-11-27        2         OAK         CAR     4      0
# 50     2016-11-27        2         OAK         CAR     0      0
# ...           ...      ...         ...         ...   ...    ...
# 45921  2017-01-01        2          LA         ARI     3     14
# 45922  2017-01-01        2          LA         ARI     4      0
# 45923  2017-01-01        2         ARI          LA     1      4
# 45924  2017-01-01        3         ARI          LA     1      0
# 45925  2017-01-01        3         ARI          LA     2      2
# 45926  2017-01-01        3         ARI          LA     3      4
# 45927  2017-01-01        3         ARI          LA     3      1
# 45928  2017-01-01        4         ARI          LA     1      0
# 45929  2017-01-01        4          LA         ARI     1      0
# 45930  2017-01-01        4          LA         ARI     2      3
# 45931  2017-01-01        4          LA         ARI     3      9
# 45932  2017-01-01        4          LA         ARI     1      0
# 45933  2017-01-01        4         ARI          LA     2      8
# 45934  2017-01-01        1          KC          SD     2      0
# 45935  2017-01-01        1          KC          SD     3     -2
# 45936  2017-01-01        1          SD          KC     2      2
# 45937  2017-01-01        1          SD          KC     3      2
# 45938  2017-01-01        1          SD          KC     4      5
# 45939  2017-01-01        2          SD          KC     0      0
# 45940  2017-01-01        2          KC          SD     1      5
# 45941  2017-01-01        2          KC          SD     2      2
# 45942  2017-01-01        2          KC          SD     1      2
# 45943  2017-01-01        2          KC          SD     1     13
# 45944  2017-01-01        3          KC          SD     1      1
# 45945  2017-01-01        3          KC          SD     2      4
# 45946  2017-01-01        3          KC          SD     3      9
# 45947  2017-01-01        3          KC          SD     3      4
# 45948  2017-01-01        1          SF         SEA     2      5
# 45949  2017-01-01        2         SEA          SF     1      1
# 45950  2017-01-01        2         SEA          SF     0      0
#
#                Formation  IsRush  IsPass  IsSack          ...           \
# 6           UNDER CENTER       0       0       0          ...
# 8                SHOTGUN       0       1       0          ...
# 15               SHOTGUN       0       1       0          ...
# 16               SHOTGUN       0       1       0          ...
# 17          UNDER CENTER       0       0       0          ...
# 18                  PUNT       0       0       0          ...
# 19               SHOTGUN       0       1       0          ...
# 21                  PUNT       0       0       0          ...
# 22               SHOTGUN       0       1       0          ...
# 23          UNDER CENTER       0       0       0          ...
# 24          UNDER CENTER       1       0       0          ...
# 27          UNDER CENTER       1       0       0          ...
# 30          UNDER CENTER       0       0       0          ...
# 31               SHOTGUN       1       0       0          ...
# 32               SHOTGUN       1       0       0          ...
# 33               SHOTGUN       0       0       0          ...
# 34               SHOTGUN       0       1       0          ...
# 35               SHOTGUN       1       0       0          ...
# 36          UNDER CENTER       0       0       0          ...
# 37     NO HUDDLE SHOTGUN       1       0       0          ...
# 39          UNDER CENTER       1       0       0          ...
# 40          UNDER CENTER       1       0       0          ...
# 41          UNDER CENTER       1       0       0          ...
# 42     NO HUDDLE SHOTGUN       0       1       0          ...
# 45          UNDER CENTER       1       0       0          ...
# 46             NO HUDDLE       1       0       0          ...
# 47               SHOTGUN       0       1       0          ...
# 48               SHOTGUN       0       1       0          ...
# 49            FIELD GOAL       0       0       0          ...
# 50          UNDER CENTER       0       0       0          ...
# ...                  ...     ...     ...     ...          ...
# 45921            SHOTGUN       0       1       0          ...
# 45922         FIELD GOAL       0       0       0          ...
# 45923            SHOTGUN       0       1       0          ...
# 45924       UNDER CENTER       1       0       0          ...
# 45925       UNDER CENTER       1       0       0          ...
# 45926            SHOTGUN       0       1       0          ...
# 45927       UNDER CENTER       1       0       0          ...
# 45928       UNDER CENTER       0       1       0          ...
# 45929            SHOTGUN       0       1       0          ...
# 45930            SHOTGUN       0       1       0          ...
# 45931            SHOTGUN       0       1       0          ...
# 45932            SHOTGUN       0       0       0          ...
# 45933       UNDER CENTER       0       1       0          ...
# 45934            SHOTGUN       0       1       0          ...
# 45935            SHOTGUN       0       0       1          ...
# 45936            SHOTGUN       0       1       0          ...
# 45937            SHOTGUN       0       1       0          ...
# 45938       UNDER CENTER       1       0       0          ...
# 45939       UNDER CENTER       0       0       0          ...
# 45940            SHOTGUN       1       0       0          ...
# 45941       UNDER CENTER       1       0       0          ...
# 45942       UNDER CENTER       1       0       0          ...
# 45943            SHOTGUN       1       0       0          ...
# 45944       UNDER CENTER       1       0       0          ...
# 45945            SHOTGUN       1       0       0          ...
# 45946            SHOTGUN       0       1       0          ...
# 45947            SHOTGUN       1       0       0          ...
# 45948  NO HUDDLE SHOTGUN       0       1       0          ...
# 45949       UNDER CENTER       1       0       0          ...
# 45950       UNDER CENTER       0       0       0          ...
#
#        KICK OFF  NO PLAY  PASS  PENALTY  PUNT  QB KNEEL  RUSH  SACK  SCRAMBLE  \
# 6             0        0     0        0     0         0     0     0         0
# 8             0        0     1        0     0         0     0     0         0
# 15            0        0     1        0     0         0     0     0         0
# 16            0        0     1        0     0         0     0     0         0
# 17            0        0     0        0     1         0     0     0         0
# 18            0        0     0        0     1         0     0     0         0
# 19            0        0     1        0     0         0     0     0         0
# 21            0        0     0        0     1         0     0     0         0
# 22            0        0     1        0     0         0     0     0         0
# 23            0        0     0        0     0         0     0     0         0
# 24            0        0     0        0     0         0     1     0         0
# 27            0        0     0        0     0         0     1     0         0
# 30            1        0     0        0     0         0     0     0         0
# 31            0        0     0        0     0         0     1     0         0
# 32            0        0     0        0     0         0     1     0         0
# 33            0        1     0        0     0         0     0     0         0
# 34            0        0     1        0     0         0     0     0         0
# 35            0        0     0        0     0         0     1     0         0
# 36            1        0     0        0     0         0     0     0         0
# 37            0        0     0        0     0         0     1     0         0
# 39            0        0     0        0     0         0     1     0         0
# 40            0        0     0        0     0         0     1     0         0
# 41            0        0     0        0     0         0     1     0         0
# 42            0        0     1        0     0         0     0     0         0
# 45            0        0     0        0     0         0     1     0         0
# 46            0        0     0        0     0         0     1     0         0
# 47            0        0     1        0     0         0     0     0         0
# 48            0        0     1        0     0         0     0     0         0
# 49            0        0     0        0     0         0     0     0         0
# 50            0        0     0        0     0         0     0     0         0
# ...         ...      ...   ...      ...   ...       ...   ...   ...       ...
# 45921         0        0     1        0     0         0     0     0         0
# 45922         0        0     0        0     0         0     0     0         0
# 45923         0        0     1        0     0         0     0     0         0
# 45924         0        0     0        0     0         0     1     0         0
# 45925         0        0     0        0     0         0     1     0         0
# 45926         0        0     1        0     0         0     0     0         0
# 45927         0        0     0        0     0         0     1     0         0
# 45928         0        0     1        0     0         0     0     0         0
# 45929         0        0     1        0     0         0     0     0         0
# 45930         0        0     1        0     0         0     0     0         0
# 45931         0        0     1        0     0         0     0     0         0
# 45932         0        1     0        0     0         0     0     0         0
# 45933         0        0     1        0     0         0     0     0         0
# 45934         0        0     1        0     0         0     0     0         0
# 45935         0        0     0        0     0         0     0     1         0
# 45936         0        0     1        0     0         0     0     0         0
# 45937         0        0     1        0     0         0     0     0         0
# 45938         0        0     0        0     0         0     1     0         0
# 45939         0        0     0        0     0         0     0     0         0
# 45940         0        0     0        0     0         0     1     0         0
# 45941         0        0     0        0     0         0     1     0         0
# 45942         0        0     0        0     0         0     1     0         0
# 45943         0        0     0        0     0         0     1     0         0
# 45944         0        0     0        0     0         0     1     0         0
# 45945         0        0     0        0     0         0     0     0         1
# 45946         0        0     1        0     0         0     0     0         0
# 45947         0        0     0        0     0         0     0     0         1
# 45948         0        0     1        0     0         0     0     0         0
# 45949         0        0     0        0     0         0     1     0         0
# 45950         0        0     0        0     0         0     0     0         0
#
#        TWO-POINT CONVERSION
# 6                         0
# 8                         0
# 15                        0
# 16                        0
# 17                        0
# 18                        0
# 19                        0
# 21                        0
# 22                        0
# 23                        1
# 24                        0
# 27                        0
# 30                        0
# 31                        0
# 32                        0
# 33                        0
# 34                        0
# 35                        0
# 36                        0
# 37                        0
# 39                        0
# 40                        0
# 41                        0
# 42                        0
# 45                        0
# 46                        0
# 47                        0
# 48                        0
# 49                        0
# 50                        0
# ...                     ...
# 45921                     0
# 45922                     0
# 45923                     0
# 45924                     0
# 45925                     0
# 45926                     0
# 45927                     0
# 45928                     0
# 45929                     0
# 45930                     0
# 45931                     0
# 45932                     0
# 45933                     0
# 45934                     0
# 45935                     0
# 45936                     0
# 45937                     0
# 45938                     0
# 45939                     0
# 45940                     0
# 45941                     0
# 45942                     0
# 45943                     0
# 45944                     0
# 45945                     0
# 45946                     0
# 45947                     0
# 45948                     0
# 45949                     0
# 45950                     0
#
# [42536 rows x 28 columns]

# %%
df = pd.read_csv("Madden-NFL-17-Launch-Ratings-Full-League.csv")
df = df[["First", "Last", "Team", "Position", "OVR"]]
#read the csv file, and take the first last team position and ovr - abhi

df = df.sort_values("OVR", ascending=False)
#sort based on OVR in descending order - abhi

teams =  np.unique(df[['Team']])
#put all the data from 'Team' into a list teams -abhi

posi = np.unique(df[['Position']])
#put all the data from 'position' into a list position -abhi

#scores = np.unique(df[['OVR']])
#put all the data from 'OVR' into a list score -abhi

# %%
OSet = {'C','RT','RG','LT','LG','WR','HB','QB','TE'}
DSet = {'CB','DT','LE','RE','MLB','LOLB','ROLB','SS','FS'}
posList = {'C': 1, 'CB': 2, 'DT' : 2, 'FS' : 1,'FB':0,'K':0,'P':0, 'HB' : 2, 'LE' : 1, 'LG' : 1, 'LOLB' : 1, 'LT' : 1, 'MLB' : 2, 'QB' : 1, 'RE' : 1, 'RG' : 1, 'ROLB' : 1, 'RT': 1, 'SS':1,'TE':1, 'WR' : 3}

# %%
filtered = []
refiltered = []

newdf = pd.DataFrame()



for i in teams:
    for p in posi:
        #nested for loop
        #append two things, from the df data structure, take the "team" value at i and
        #the "position" value at p
        #Take the head(1), which is the first part of the df data structure, and take the value
        #I wanna take only a set number of positions, 
        filtered.append((df[(df["Team"]==i) & (df["Position"] == p)].head(posList[p])))
#         newdf.append((df[(df["Team"]==i) & (df["Position"] == p)].head(posList[p])))

df = pd.concat(filtered)
df
# Out:
#           First         Last     Team Position  OVR
# 1051     Daniel      Kilgore    49ers        C   71
# 325    Tramaine        Brock    49ers       CB   81
# 712      Dontae      Johnson    49ers       CB   75
# 280         Ian     Williams    49ers       DT   82
# 1820       Mike      Purcell    49ers       DT   64
# 569        Eric         Reid    49ers       FS   77
# 326      Carlos         Hyde    49ers       HB   81
# 857       Shaun      Draughn    49ers       HB   73
# 565        Arik     Armstead    49ers       LE   77
# 856        Zane      Beadles    49ers       LG   73
# 769       Ahmad       Brooks    49ers     LOLB   74
# 77          Joe       Staley    49ers       LT   89
# 99      NaVorro       Bowman    49ers      MLB   88
# 1177    Michael     Wilhoite    49ers      MLB   70
# 772       Colin   Kaepernick    49ers       QB   74
# 496    DeForest      Buckner    49ers       RE   78
# 771      Joshua      Garnett    49ers       RG   74
# 236       Aaron        Lynch    49ers     ROLB   83
# 497     Anthony        Davis    49ers       RT   78
# 566     Antoine       Bethea    49ers       SS   77
# 498       Vance     McDonald    49ers       TE   78
# 499      Torrey        Smith    49ers       WR   78
# 1176    Quinton       Patton    49ers       WR   70
# 1289      Bruce    Ellington    49ers       WR   69
# 1399    Hroniss        Grasu    Bears        C   68
# 388        Kyle       Fuller    Bears       CB   80
# 948       Tracy       Porter    Bears       CB   72
# 633       Eddie      Goldman    Bears       DT   76
# 2164     Kenton      Adeyemi    Bears       DT   60
# 570      Adrian         Amos    Bears       FS   77
# ...         ...          ...      ...      ...  ...
# 490        Jack      Conklin   Titans       RT   79
# 206   Da'Norris       Searcy   Titans       SS   85
# 34      Delanie       Walker   Titans       TE   93
# 493     Kendall       Wright   Titans       WR   79
# 492     Rishard     Matthews   Titans       WR   79
# 707       Andre      Johnson   Titans       WR   76
# 174        John     Sullivan  Vikings        C   86
# 436     Terence       Newman  Vikings       CB   80
# 437      Xavier       Rhodes  Vikings       CB   80
# 98       Linval       Joseph  Vikings       DT   89
# 279     Sharrif        Floyd  Vikings       DT   83
# 19     Harrison        Smith  Vikings       FS   94
# 60       Adrian     Peterson  Vikings       HB   91
# 709      Jerick     McKinnon  Vikings       HB   76
# 495       Brian      Robison  Vikings       LE   79
# 1043    Brandon        Fusco  Vikings       LG   72
# 126     Anthony         Barr  Vikings     LOLB   88
# 435        Matt        Kalil  Vikings       LT   80
# 708        Eric    Kendricks  Vikings      MLB   76
# 1611      Audie         Cole  Vikings      MLB   67
# 383       Teddy  Bridgewater  Vikings       QB   81
# 127     Everson      Griffen  Vikings       RE   88
# 382        Alex        Boone  Vikings       RG   81
# 562        Chad     Greenway  Vikings     ROLB   78
# 631       Andre        Smith  Vikings       RT   77
# 564      Andrew      Sendejo  Vikings       SS   78
# 384        Kyle      Rudolph  Vikings       TE   81
# 494      Stefon        Diggs  Vikings       WR   79
# 767      Laquon    Treadwell  Vikings       WR   75
# 768      Jarius       Wright  Vikings       WR   75
#
# [768 rows x 5 columns]

# %%
##Data structure for each team
new49 = pd.DataFrame()

# %%
numList = []
for j in filtered:
    for l in j:
        for z in l:
            if isinstance(z, int):
                numList.append(z)

# %%
df = df.drop(['First', 'Last'], axis = 1)

# %%
sorter = {'C':1,'RT':2,'RG':3,'LT':4,'LG':5,'WR':6,'HB':7,'QB':8,'TE':9,'CB':10,'DT':11,'LE':12,'RE':13,'MLB':14,'LOLB':15,'ROLB':16,'SS':17,'FS':18}

df['value'] = df.apply(lambda row: sorter[row.Position], axis=1)
df = df.sort_values(by=['Team', 'value', 'OVR'])
df = df.drop(['value', 'Position'], axis = 1)

# %%
test = df.values

# %%
np.asmatrix(test)
# Out:
# matrix([['49ers', 71],
#         ['49ers', 78],
#         ['49ers', 74],
#         ...,
#         ['Vikings', 78],
#         ['Vikings', 78],
#         ['Vikings', 94]], dtype=object)

# %%
Stringtest = np.array2string(test[1])
import re
Stringtest
# Out:
# "['49ers' 78]"

# %%
 np.array_str(np.arange(3))
# Out:
# '[0 1 2]'

# %%
# Out:
# array([['49ers', 71],
#        ['49ers', 78],
#        ['49ers', 74],
#        ...,
#        ['Vikings', 78],
#        ['Vikings', 78],
#        ['Vikings', 94]], dtype=object)

# %%
TeamDict = {'Cardinals' : 'ARI', 'Falcons': 'ATL', 'Ravens': 'BAL', 'Bills': 'BUF', 'Panthers': 'CAR', 'Bears': 'CHI',
'Bengals': 'CIN', 'Browns': 'CLE', 'Cowboys': 'DAL', 'Broncos': 'DEN', 'Lions': 'DET', 'Packers': 'GB', 'Texans': 'HOU',
'Colts': 'IND', 'Jaguars': 'JAX', 'Chiefs': 'KC', 'Dolphins': 'MIA', 'Vikings': 'MIN', 'Patriots': 'NE', 'Saints': 'NO',
'Giants': 'NYG', 'Jets': 'NYJ', 'Raiders': 'OAK', 'Eagles': 'PHI', 'Steelers': 'PIT', 'Chargers': 'SD', 'ers': 'SF',
'Seahawks': 'SEA', 'Rams': 'LA', 'Buccaneers': 'TB', 'Titans': 'TEN', 'Redskins': 'WAS'}
ODict = {'ARI': 0, 'ATL':0, 'BAL':0, 'BUF':0, 'CAR':0, 'CHI':0, 'CIN':0, 'CLE':0, 'DAL':0, 'DEN':0, 'DET':0, 'GB':0, 'HOU':0,
'IND':0, 'JAX':0, 'KC':0, 'MIA':0, 'MIN':0, 'NE':0, 'NO':0, 'NYG':0, 'NYJ':0, 'OAK':0, 'PHI':0, 'PIT':0, 'SD':0, 'SF':0, 'SEA':0,
'LA':0, 'TB':0, 'TEN':0, 'WAS':0}
DDict = {'ARI': 0, 'ATL':0, 'BAL':0, 'BUF':0, 'CAR':0, 'CHI':0, 'CIN':0, 'CLE':0, 'DAL':0, 'DEN':0, 'DET':0, 'GB':0, 'HOU':0,
'IND':0, 'JAX':0, 'KC':0, 'MIA':0, 'MIN':0, 'NE':0, 'NO':0, 'NYG':0, 'NYJ':0, 'OAK':0, 'PHI':0, 'PIT':0, 'SD':0, 'SF':0, 'SEA':0,
'LA':0, 'TB':0, 'TEN':0, 'WAS':0}
count = 0
for i in test:
    x = count
    y = TeamDict[re.sub("[^a-zA-Z]+", "", np.array2string(i))]
    while(x > 11):
        x = x - 12
    z =  np.array2string(i)
    if x < 6:
       
        
        ODict[y] = (ODict[y] + (int(z[len(z)-3])*10) + int(z[len(z)-2]) )
        
            
    else:
        DDict[y] = (ODict[y] + (int(z[len(z)-3])*10) + int(z[len(z)-2]) * 10)
    count = count + 1
    
    
for i in ODict:
    ODict[i] = ODict[i] / 12
for i in DDict:
    DDict[i] =DDict[i] / 12
DDict
# Out:
# {'ARI': 92.33333333333333,
#  'ATL': 89.33333333333333,
#  'BAL': 87.41666666666667,
#  'BUF': 89.41666666666667,
#  'CAR': 93.58333333333333,
#  'CHI': 83.91666666666667,
#  'CIN': 91.41666666666667,
#  'CLE': 90.33333333333333,
#  'DAL': 90.16666666666667,
#  'DEN': 87.33333333333333,
#  'DET': 87.41666666666667,
#  'GB': 90.08333333333333,
#  'HOU': 92.5,
#  'IND': 83.91666666666667,
#  'JAX': 90.25,
#  'KC': 86.91666666666667,
#  'LA': 90.66666666666667,
#  'MIA': 89.83333333333333,
#  'MIN': 91.66666666666667,
#  'NE': 88.33333333333333,
#  'NO': 88.83333333333333,
#  'NYG': 91.5,
#  'NYJ': 86.33333333333333,
#  'OAK': 93.91666666666667,
#  'PHI': 91.58333333333333,
#  'PIT': 88.91666666666667,
#  'SD': 92.66666666666667,
#  'SEA': 88.16666666666667,
#  'SF': 87.58333333333333,
#  'TB': 90.58333333333333,
#  'TEN': 85.0,
#  'WAS': 87.33333333333333}

# %%
data['Skill diffrence'] = data.apply(lambda row: ODict[row.OffenseTeam] - DDict[row.DefenseTeam], axis=1)

# %%
data
# Out:
#          GameDate  Quarter OffenseTeam DefenseTeam  Down  Yards  \
# 6      2016-09-11        2         HOU         CHI     0      0
# 8      2016-09-11        3         HOU         CHI     1      0
# 15     2016-09-11        2          NO         OAK     2      6
# 16     2016-09-11        2          NO         OAK     3      0
# 17     2016-09-11        2          NO         OAK     4      0
# 18     2016-09-11        2          NO         OAK     4      0
# 19     2016-09-11        2         OAK          NO     1      9
# 21     2016-09-11        3          NO         OAK     4      0
# 22     2016-09-11        3          NO         OAK     2      1
# 23     2016-09-11        4         OAK          NO     0      0
# 24     2016-09-11        4         OAK          NO     1      1
# 27     2016-09-11        2         CIN         NYJ     2      4
# 30     2016-09-11        1         CLE         PHI     0      0
# 31     2016-09-11        1         PHI         CLE     1      6
# 32     2016-09-11        1         PHI         CLE     2      1
# 33     2016-09-11        1         PHI         CLE     3      0
# 34     2016-09-11        1         PHI         CLE     1      0
# 35     2016-09-11        1         PHI         CLE     1      5
# 36     2016-09-11        3         PHI         CLE     0      0
# 37     2016-09-11        3         CLE         PHI     1      0
# 39     2016-09-11        1         MIN         TEN     2      1
# 40     2016-09-11        2         MIN         TEN     3      6
# 41     2016-09-11        2         MIN         TEN     1      2
# 42     2016-09-11        2         TEN         MIN     3     16
# 45     2016-09-11        3         MIN         TEN     1      2
# 46     2016-09-11        3         MIN         TEN     1      3
# 47     2016-11-27        2         OAK         CAR     2      0
# 48     2016-11-27        2         OAK         CAR     3      0
# 49     2016-11-27        2         OAK         CAR     4      0
# 50     2016-11-27        2         OAK         CAR     0      0
# ...           ...      ...         ...         ...   ...    ...
# 45921  2017-01-01        2          LA         ARI     3     14
# 45922  2017-01-01        2          LA         ARI     4      0
# 45923  2017-01-01        2         ARI          LA     1      4
# 45924  2017-01-01        3         ARI          LA     1      0
# 45925  2017-01-01        3         ARI          LA     2      2
# 45926  2017-01-01        3         ARI          LA     3      4
# 45927  2017-01-01        3         ARI          LA     3      1
# 45928  2017-01-01        4         ARI          LA     1      0
# 45929  2017-01-01        4          LA         ARI     1      0
# 45930  2017-01-01        4          LA         ARI     2      3
# 45931  2017-01-01        4          LA         ARI     3      9
# 45932  2017-01-01        4          LA         ARI     1      0
# 45933  2017-01-01        4         ARI          LA     2      8
# 45934  2017-01-01        1          KC          SD     2      0
# 45935  2017-01-01        1          KC          SD     3     -2
# 45936  2017-01-01        1          SD          KC     2      2
# 45937  2017-01-01        1          SD          KC     3      2
# 45938  2017-01-01        1          SD          KC     4      5
# 45939  2017-01-01        2          SD          KC     0      0
# 45940  2017-01-01        2          KC          SD     1      5
# 45941  2017-01-01        2          KC          SD     2      2
# 45942  2017-01-01        2          KC          SD     1      2
# 45943  2017-01-01        2          KC          SD     1     13
# 45944  2017-01-01        3          KC          SD     1      1
# 45945  2017-01-01        3          KC          SD     2      4
# 45946  2017-01-01        3          KC          SD     3      9
# 45947  2017-01-01        3          KC          SD     3      4
# 45948  2017-01-01        1          SF         SEA     2      5
# 45949  2017-01-01        2         SEA          SF     1      1
# 45950  2017-01-01        2         SEA          SF     0      0
#
#                Formation  IsRush  IsPass  IsSack       ...         NO PLAY  \
# 6           UNDER CENTER       0       0       0       ...               0
# 8                SHOTGUN       0       1       0       ...               0
# 15               SHOTGUN       0       1       0       ...               0
# 16               SHOTGUN       0       1       0       ...               0
# 17          UNDER CENTER       0       0       0       ...               0
# 18                  PUNT       0       0       0       ...               0
# 19               SHOTGUN       0       1       0       ...               0
# 21                  PUNT       0       0       0       ...               0
# 22               SHOTGUN       0       1       0       ...               0
# 23          UNDER CENTER       0       0       0       ...               0
# 24          UNDER CENTER       1       0       0       ...               0
# 27          UNDER CENTER       1       0       0       ...               0
# 30          UNDER CENTER       0       0       0       ...               0
# 31               SHOTGUN       1       0       0       ...               0
# 32               SHOTGUN       1       0       0       ...               0
# 33               SHOTGUN       0       0       0       ...               1
# 34               SHOTGUN       0       1       0       ...               0
# 35               SHOTGUN       1       0       0       ...               0
# 36          UNDER CENTER       0       0       0       ...               0
# 37     NO HUDDLE SHOTGUN       1       0       0       ...               0
# 39          UNDER CENTER       1       0       0       ...               0
# 40          UNDER CENTER       1       0       0       ...               0
# 41          UNDER CENTER       1       0       0       ...               0
# 42     NO HUDDLE SHOTGUN       0       1       0       ...               0
# 45          UNDER CENTER       1       0       0       ...               0
# 46             NO HUDDLE       1       0       0       ...               0
# 47               SHOTGUN       0       1       0       ...               0
# 48               SHOTGUN       0       1       0       ...               0
# 49            FIELD GOAL       0       0       0       ...               0
# 50          UNDER CENTER       0       0       0       ...               0
# ...                  ...     ...     ...     ...       ...             ...
# 45921            SHOTGUN       0       1       0       ...               0
# 45922         FIELD GOAL       0       0       0       ...               0
# 45923            SHOTGUN       0       1       0       ...               0
# 45924       UNDER CENTER       1       0       0       ...               0
# 45925       UNDER CENTER       1       0       0       ...               0
# 45926            SHOTGUN       0       1       0       ...               0
# 45927       UNDER CENTER       1       0       0       ...               0
# 45928       UNDER CENTER       0       1       0       ...               0
# 45929            SHOTGUN       0       1       0       ...               0
# 45930            SHOTGUN       0       1       0       ...               0
# 45931            SHOTGUN       0       1       0       ...               0
# 45932            SHOTGUN       0       0       0       ...               1
# 45933       UNDER CENTER       0       1       0       ...               0
# 45934            SHOTGUN       0       1       0       ...               0
# 45935            SHOTGUN       0       0       1       ...               0
# 45936            SHOTGUN       0       1       0       ...               0
# 45937            SHOTGUN       0       1       0       ...               0
# 45938       UNDER CENTER       1       0       0       ...               0
# 45939       UNDER CENTER       0       0       0       ...               0
# 45940            SHOTGUN       1       0       0       ...               0
# 45941       UNDER CENTER       1       0       0       ...               0
# 45942       UNDER CENTER       1       0       0       ...               0
# 45943            SHOTGUN       1       0       0       ...               0
# 45944       UNDER CENTER       1       0       0       ...               0
# 45945            SHOTGUN       1       0       0       ...               0
# 45946            SHOTGUN       0       1       0       ...               0
# 45947            SHOTGUN       1       0       0       ...               0
# 45948  NO HUDDLE SHOTGUN       0       1       0       ...               0
# 45949       UNDER CENTER       1       0       0       ...               0
# 45950       UNDER CENTER       0       0       0       ...               0
#
#        PASS  PENALTY  PUNT  QB KNEEL  RUSH  SACK  SCRAMBLE  \
# 6         0        0     0         0     0     0         0
# 8         1        0     0         0     0     0         0
# 15        1        0     0         0     0     0         0
# 16        1        0     0         0     0     0         0
# 17        0        0     1         0     0     0         0
# 18        0        0     1         0     0     0         0
# 19        1        0     0         0     0     0         0
# 21        0        0     1         0     0     0         0
# 22        1        0     0         0     0     0         0
# 23        0        0     0         0     0     0         0
# 24        0        0     0         0     1     0         0
# 27        0        0     0         0     1     0         0
# 30        0        0     0         0     0     0         0
# 31        0        0     0         0     1     0         0
# 32        0        0     0         0     1     0         0
# 33        0        0     0         0     0     0         0
# 34        1        0     0         0     0     0         0
# 35        0        0     0         0     1     0         0
# 36        0        0     0         0     0     0         0
# 37        0        0     0         0     1     0         0
# 39        0        0     0         0     1     0         0
# 40        0        0     0         0     1     0         0
# 41        0        0     0         0     1     0         0
# 42        1        0     0         0     0     0         0
# 45        0        0     0         0     1     0         0
# 46        0        0     0         0     1     0         0
# 47        1        0     0         0     0     0         0
# 48        1        0     0         0     0     0         0
# 49        0        0     0         0     0     0         0
# 50        0        0     0         0     0     0         0
# ...     ...      ...   ...       ...   ...   ...       ...
# 45921     1        0     0         0     0     0         0
# 45922     0        0     0         0     0     0         0
# 45923     1        0     0         0     0     0         0
# 45924     0        0     0         0     1     0         0
# 45925     0        0     0         0     1     0         0
# 45926     1        0     0         0     0     0         0
# 45927     0        0     0         0     1     0         0
# 45928     1        0     0         0     0     0         0
# 45929     1        0     0         0     0     0         0
# 45930     1        0     0         0     0     0         0
# 45931     1        0     0         0     0     0         0
# 45932     0        0     0         0     0     0         0
# 45933     1        0     0         0     0     0         0
# 45934     1        0     0         0     0     0         0
# 45935     0        0     0         0     0     1         0
# 45936     1        0     0         0     0     0         0
# 45937     1        0     0         0     0     0         0
# 45938     0        0     0         0     1     0         0
# 45939     0        0     0         0     0     0         0
# 45940     0        0     0         0     1     0         0
# 45941     0        0     0         0     1     0         0
# 45942     0        0     0         0     1     0         0
# 45943     0        0     0         0     1     0         0
# 45944     0        0     0         0     1     0         0
# 45945     0        0     0         0     0     0         1
# 45946     1        0     0         0     0     0         0
# 45947     0        0     0         0     0     0         1
# 45948     1        0     0         0     0     0         0
# 45949     0        0     0         0     1     0         0
# 45950     0        0     0         0     0     0         0
#
#        TWO-POINT CONVERSION  Skill diffrence
# 6                         0        -4.750000
# 8                         0        -4.750000
# 15                        0       -14.250000
# 16                        0       -14.250000
# 17                        0       -14.250000
# 18                        0       -14.250000
# 19                        0        -7.416667
# 21                        0       -14.250000
# 22                        0       -14.250000
# 23                        1        -7.416667
# 24                        0        -7.416667
# 27                        0        -4.916667
# 30                        0       -14.583333
# 31                        0        -8.750000
# 32                        0        -8.750000
# 33                        0        -8.750000
# 34                        0        -8.750000
# 35                        0        -8.750000
# 36                        0        -8.750000
# 37                        0       -14.583333
# 39                        0        -4.166667
# 40                        0        -4.166667
# 41                        0        -4.166667
# 42                        0       -15.000000
# 45                        0        -4.166667
# 46                        0        -4.166667
# 47                        0       -12.166667
# 48                        0       -12.166667
# 49                        0       -12.166667
# 50                        0       -12.166667
# ...                     ...              ...
# 45921                     0       -13.333333
# 45922                     0       -13.333333
# 45923                     0       -10.833333
# 45924                     0       -10.833333
# 45925                     0       -10.833333
# 45926                     0       -10.833333
# 45927                     0       -10.833333
# 45928                     0       -10.833333
# 45929                     0       -13.333333
# 45930                     0       -13.333333
# 45931                     0       -13.333333
# 45932                     0       -13.333333
# 45933                     0       -10.833333
# 45934                     0       -15.750000
# 45935                     0       -15.750000
# 45936                     0        -7.583333
# 45937                     0        -7.583333
# 45938                     0        -7.583333
# 45939                     0        -7.583333
# 45940                     0       -15.750000
# 45941                     0       -15.750000
# 45942                     0       -15.750000
# 45943                     0       -15.750000
# 45944                     0       -15.750000
# 45945                     0       -15.750000
# 45946                     0       -15.750000
# 45947                     0       -15.750000
# 45948                     0       -12.250000
# 45949                     0        -9.416667
# 45950                     0        -9.416667
#
# [42536 rows x 29 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
 data.plot(kind="scatter", x="Skill diffrence", y="Yards", alpha = 0.1)

# %%
corr_matrix = data.corr()
corr_matrix["Yards"].sort_values(ascending=False)
# Out:
# Yards                   1.000000
# PASS                    0.305823
# IsPass                  0.305823
# SCRAMBLE                0.045438
# Skill diffrence         0.006929
# Quarter                -0.003138
# Down                   -0.003882
# PENALTY                -0.005823
# IsRush                 -0.007304
# RUSH                   -0.020086
# EXCEPTION              -0.020847
# CLOCK STOP             -0.021960
# FUMBLES                -0.025542
# TWO-POINT CONVERSION   -0.026588
# IsTwoPointConversion   -0.026716
# IsPenalty              -0.034058
# QB KNEEL               -0.050717
# IsNoPlay               -0.064173
# NO PLAY                -0.078103
# FIELD GOAL             -0.084517
# EXTRA POINT            -0.091543
# PUNT                   -0.132511
# KICK OFF               -0.138484
# IsSack                 -0.221307
# SACK                   -0.221307
# Name: Yards, dtype: float64
