# %%
import os
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("C:/Users/Santhoshkumar/Desktop/Abhi/pbp-2016.csv")
data = data.drop(['Minute','Second','IsTwoPointConversionSuccessful','RushDirection','YardLineFixed','YardLineDirection', 'IsPenaltyAccepted', 'PenaltyTeam','PenaltyType','PenaltyYards'], axis =1)
data = data.drop(['IsFumble','IsInterception','IsMeasurement','Challenger','IsChallengeReversed','PassType','IsTouchdown','SeriesFirstDown','Unnamed: 10','ToGo','YardLine'], axis = 1)
data = data.drop(['NextScore','Description','Unnamed: 17', 'SeasonYear','IsIncomplete','IsChallenge'], axis = 1)
data = data.drop(['Unnamed: 12','Unnamed: 16','TeamWin','GameId'],axis = 1)
data = data.dropna()
#cut all the unwanted data, cleaning - abhi
#ata = pd.concat([data, pd.get_dummies(data['Formation'])], axis =1)
#ata = data.drop(['Formation'], axis = 1)
data = pd.concat([data, pd.get_dummies(data['PlayType'])], axis =1)
data = data.drop(['PlayType'], axis = 1)
column_a = data['Yards']
column_a
b = []

# print (data.groupby(['Formation','Yards']).groups)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c9f832f93b3b> in <module>()
# ----> 1 data = pd.read_csv("C:/Users/Santhoshkumar/Desktop/Abhi/pbp-2016.csv")
#       2 data = data.drop(['Minute','Second','IsTwoPointConversionSuccessful','RushDirection','YardLineFixed','YardLineDirection', 'IsPenaltyAccepted', 'PenaltyTeam','PenaltyType','PenaltyYards'], axis =1)
#       3 data = data.drop(['IsFumble','IsInterception','IsMeasurement','Challenger','IsChallengeReversed','PassType','IsTouchdown','SeriesFirstDown','Unnamed: 10','ToGo','YardLine'], axis = 1)
#       4 data = data.drop(['NextScore','Description','Unnamed: 17', 'SeasonYear','IsIncomplete','IsChallenge'], axis = 1)
#       5 data = data.drop(['Unnamed: 12','Unnamed: 16','TeamWin','GameId'],axis = 1)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas\_libs\parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas\_libs\parsers.c:8873)()
#
# FileNotFoundError: File b'C:/Users/Santhoshkumar/Desktop/Abhi/pbp-2016.csv' does not exist

# %%
df = pd.read_csv("Madden-NFL-17-Launch-Ratings-Full-League.csv")
df = df[["First", "Last", "Team", "Position", "OVR"]]
#read the csv file, and take the first last team position and ovr - abhi

df = df.sort_values("OVR", ascending=False)
#sort based on OVR in descending order - abhi

teams =  np.unique(df[['Team']])
#put all the data from 'Team' into a list teams -abhi

posi = np.unique(df[['Position']])
#put all the data from 'position' into a list position -abhi

# %%
OSet = {'C','RT','RG','LT','LG','WR','RB','QB','TE'}
DSet = {'CB','DT','LE','RE','MLB','LOLB','ROLB','SS','FS'}
posList = {'C': 1, 'CB': 2, 'DT' : 2, 'FS' : 1,'FB':0,'K':0,'P':0, 'HB' : 2, 'LE' : 1, 'LG' : 1, 'LOLB' : 1, 'LT' : 1, 'MLB' : 2, 'QB' : 1, 'RE' : 1, 'RG' : 1, 'ROLB' : 1, 'RT': 1, 'SS':1,'TE':1, 'WR' : 3}

# %%
filtered = []
refiltered = []

for i in teams:
    for p in posi:
        #nested for loop
        #append two things, from the df data structure, take the "team" value at i and
        #the "position" value at p
        #Take the head(1), which is the first part of the df data structure, and take the value
        #I wanna take only a set number of positions, 
        filtered.append((df[(df["Team"]==i) & (df["Position"] == p)].head(posList[p]).values))

# %%
tempfill = []
for i in teams:
    for p in posi:
        if(p in OSet):
            tempfill.append((df[(df["Team"]==i) & (df["Position"] == p)].head(posList[p]).values))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c33ea4602f88> in <module>()
#       1 tempfill = []
# ----> 2 for i in teams:
#       3     for p in posi:
#       4         if(p in OSet):
#       5             tempfill.append((df[(df["Team"]==i) & (df["Position"] == p)].head(posList[p]).values))
#
# NameError: name 'teams' is not defined

# %%
filtered
# Out:
# [array([['Daniel', 'Kilgore', '49ers', 'C', 71]], dtype=object),
#  array([['Tramaine', 'Brock', '49ers', 'CB', 81],
#         ['Dontae', 'Johnson', '49ers', 'CB', 75]], dtype=object),
#  array([['Ian', 'Williams', '49ers', 'DT', 82],
#         ['Mike', 'Purcell', '49ers', 'DT', 64]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Eric', 'Reid', '49ers', 'FS', 77]], dtype=object),
#  array([['Carlos', 'Hyde', '49ers', 'HB', 81],
#         ['Shaun', 'Draughn', '49ers', 'HB', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Arik', 'Armstead', '49ers', 'LE', 77]], dtype=object),
#  array([['Zane', 'Beadles', '49ers', 'LG', 73]], dtype=object),
#  array([['Ahmad', 'Brooks', '49ers', 'LOLB', 74]], dtype=object),
#  array([['Joe', 'Staley', '49ers', 'LT', 89]], dtype=object),
#  array([['NaVorro', 'Bowman', '49ers', 'MLB', 88],
#         ['Michael', 'Wilhoite', '49ers', 'MLB', 70]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Colin', 'Kaepernick', '49ers', 'QB', 74]], dtype=object),
#  array([['DeForest', 'Buckner', '49ers', 'RE', 78]], dtype=object),
#  array([['Joshua', 'Garnett', '49ers', 'RG', 74]], dtype=object),
#  array([['Aaron', 'Lynch', '49ers', 'ROLB', 83]], dtype=object),
#  array([['Anthony', 'Davis', '49ers', 'RT', 78]], dtype=object),
#  array([['Antoine', 'Bethea', '49ers', 'SS', 77]], dtype=object),
#  array([['Vance', 'McDonald', '49ers', 'TE', 78]], dtype=object),
#  array([['Torrey', 'Smith', '49ers', 'WR', 78],
#         ['Quinton', 'Patton', '49ers', 'WR', 70],
#         ['Bruce', 'Ellington', '49ers', 'WR', 69]], dtype=object),
#  array([['Hroniss', 'Grasu', 'Bears', 'C', 68]], dtype=object),
#  array([['Kyle', 'Fuller', 'Bears', 'CB', 80],
#         ['Tracy', 'Porter', 'Bears', 'CB', 72]], dtype=object),
#  array([['Eddie', 'Goldman', 'Bears', 'DT', 76],
#         ['Kenton', 'Adeyemi', 'Bears', 'DT', 60]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Adrian', 'Amos', 'Bears', 'FS', 77]], dtype=object),
#  array([['Jeremy', 'Langford', 'Bears', 'HB', 76],
#         ['Jacquizz', 'Rodgers', 'Bears', 'HB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Akiem', 'Hicks', 'Bears', 'LE', 78]], dtype=object),
#  array([['Cody', 'Whitehair', 'Bears', 'LG', 69]], dtype=object),
#  array([['Pernell', 'McPhee', 'Bears', 'LOLB', 92]], dtype=object),
#  array([['Charles', 'Leno Jr.', 'Bears', 'LT', 68]], dtype=object),
#  array([['Jerrell', 'Freeman', 'Bears', 'MLB', 86],
#         ['Danny', 'Trevathan', 'Bears', 'MLB', 85]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Jay', 'Cutler', 'Bears', 'QB', 80]], dtype=object),
#  array([['Mitch', 'Unrein', 'Bears', 'RE', 68]], dtype=object),
#  array([['Kyle', 'Long', 'Bears', 'RG', 79]], dtype=object),
#  array([['Lamarr', 'Houston', 'Bears', 'ROLB', 81]], dtype=object),
#  array([['Bobby', 'Massie', 'Bears', 'RT', 75]], dtype=object),
#  array([['Chris', 'Prosinski', 'Bears', 'SS', 69]], dtype=object),
#  array([['Zach', 'Miller', 'Bears', 'TE', 78]], dtype=object),
#  array([['Alshon', 'Jeffery', 'Bears', 'WR', 91],
#         ['Eddie', 'Royal', 'Bears', 'WR', 77],
#         ['Kevin', 'White', 'Bears', 'WR', 74]], dtype=object),
#  array([['Russell', 'Bodine', 'Bengals', 'C', 69]], dtype=object),
#  array([['Adam', 'Jones', 'Bengals', 'CB', 88],
#         ['Dre', 'Kirkpatrick', 'Bengals', 'CB', 76]], dtype=object),
#  array([['Geno', 'Atkins', 'Bengals', 'DT', 94],
#         ['Domata', 'Peko', 'Bengals', 'DT', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['George', 'Iloka', 'Bengals', 'FS', 84]], dtype=object),
#  array([['Giovani', 'Bernard', 'Bengals', 'HB', 85],
#         ['Jeremy', 'Hill', 'Bengals', 'HB', 81]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Carlos', 'Dunlap', 'Bengals', 'LE', 87]], dtype=object),
#  array([['Clint', 'Boling', 'Bengals', 'LG', 81]], dtype=object),
#  array([['Karlos', 'Dansby', 'Bengals', 'LOLB', 83]], dtype=object),
#  array([['Andrew', 'Whitworth', 'Bengals', 'LT', 93]], dtype=object),
#  array([['Rey', 'Maualuga', 'Bengals', 'MLB', 84],
#         ['Vincent', 'Rey', 'Bengals', 'MLB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Andy', 'Dalton', 'Bengals', 'QB', 87]], dtype=object),
#  array([['Michael', 'Johnson', 'Bengals', 'RE', 79]], dtype=object),
#  array([['Kevin', 'Zeitler', 'Bengals', 'RG', 89]], dtype=object),
#  array([['Vontaze', 'Burfict', 'Bengals', 'ROLB', 88]], dtype=object),
#  array([['Jake', 'Fisher', 'Bengals', 'RT', 77]], dtype=object),
#  array([['Shawn', 'Williams', 'Bengals', 'SS', 75]], dtype=object),
#  array([['Tyler', 'Eifert', 'Bengals', 'TE', 90]], dtype=object),
#  array([['A.J.', 'Green', 'Bengals', 'WR', 93],
#         ['Brandon', 'LaFell', 'Bengals', 'WR', 77],
#         ['Brandon', 'Tate', 'Bengals', 'WR', 71]], dtype=object),
#  array([['Eric', 'Wood', 'Bills', 'C', 81]], dtype=object),
#  array([['Stephon', 'Gilmore', 'Bills', 'CB', 85],
#         ['Ronald', 'Darby', 'Bills', 'CB', 83]], dtype=object),
#  array([['Marcell', 'Dareus', 'Bills', 'DT', 88],
#         ['Kyle', 'Williams', 'Bills', 'DT', 82]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Corey', 'Graham', 'Bills', 'FS', 82]], dtype=object),
#  array([['LeSean', 'McCoy', 'Bills', 'HB', 86],
#         ['Karlos', 'Williams Sr.', 'Bills', 'HB', 79]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Shaq', 'Lawson', 'Bills', 'LE', 75]], dtype=object),
#  array([['Richie', 'Incognito', 'Bills', 'LG', 90]], dtype=object),
#  array([['Lorenzo', 'Alexander', 'Bills', 'LOLB', 72]], dtype=object),
#  array([['Cordy', 'Glenn', 'Bills', 'LT', 89]], dtype=object),
#  array([['Preston', 'Brown', 'Bills', 'MLB', 73],
#         ['Jamari', 'Lattimore', 'Bills', 'MLB', 70]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Tyrod', 'Taylor', 'Bills', 'QB', 82]], dtype=object),
#  array([['Jerry', 'Hughes', 'Bills', 'RE', 88]], dtype=object),
#  array([['John', 'Miller', 'Bills', 'RG', 69]], dtype=object),
#  array([['Zach', 'Brown', 'Bills', 'ROLB', 82]], dtype=object),
#  array([['Jordan', 'Mills', 'Bills', 'RT', 73]], dtype=object),
#  array([['Aaron', 'Williams', 'Bills', 'SS', 77]], dtype=object),
#  array([['Charles', 'Clay', 'Bills', 'TE', 84]], dtype=object),
#  array([['Sammy', 'Watkins', 'Bills', 'WR', 87],
#         ['Robert', 'Woods', 'Bills', 'WR', 73],
#         ['Leonard', 'Hankerson', 'Bills', 'WR', 70]], dtype=object),
#  array([['Matt', 'Paradis', 'Broncos', 'C', 71]], dtype=object),
#  array([['Chris', 'Harris Jr.', 'Broncos', 'CB', 93],
#         ['Aqib', 'Talib', 'Broncos', 'CB', 90]], dtype=object),
#  array([['Sylvester', 'Williams', 'Broncos', 'DT', 74],
#         ['Darius', 'Kilgo', 'Broncos', 'DT', 61]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Darian', 'Stewart', 'Broncos', 'FS', 86]], dtype=object),
#  array([['C.J.', 'Anderson', 'Broncos', 'HB', 84],
#         ['Ronnie', 'Hillman', 'Broncos', 'HB', 76]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Derek', 'Wolfe', 'Broncos', 'LE', 86]], dtype=object),
#  array([['Max', 'Garcia', 'Broncos', 'LG', 70]], dtype=object),
#  array([['Von', 'Miller', 'Broncos', 'LOLB', 99]], dtype=object),
#  array([['Russell', 'Okung', 'Broncos', 'LT', 82]], dtype=object),
#  array([['Brandon', 'Marshall', 'Broncos', 'MLB', 90],
#         ['Todd', 'Davis', 'Broncos', 'MLB', 64]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Paxton', 'Lynch', 'Broncos', 'QB', 74]], dtype=object),
#  array([['Jared', 'Crick', 'Broncos', 'RE', 70]], dtype=object),
#  array([['Connor', 'McGovern', 'Broncos', 'RG', 66]], dtype=object),
#  array([['DeMarcus', 'Ware', 'Broncos', 'ROLB', 86]], dtype=object),
#  array([['Donald', 'Stephenson', 'Broncos', 'RT', 72]], dtype=object),
#  array([['T.J.', 'Ward', 'Broncos', 'SS', 85]], dtype=object),
#  array([['Virgil', 'Green', 'Broncos', 'TE', 79]], dtype=object),
#  array([['Emmanuel', 'Sanders', 'Broncos', 'WR', 88],
#         ['Demaryius', 'Thomas', 'Broncos', 'WR', 87],
#         ['Marlon', 'Brown', 'Broncos', 'WR', 73]], dtype=object),
#  array([['Cameron', 'Erving', 'Browns', 'C', 68]], dtype=object),
#  array([['Joe', 'Haden', 'Browns', 'CB', 86],
#         ['Tramon', 'Williams', 'Browns', 'CB', 80]], dtype=object),
#  array([['Danny', 'Shelton', 'Browns', 'DT', 72],
#         ['Jamie', 'Meder', 'Browns', 'DT', 69]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Rahim', 'Moore Sr.', 'Browns', 'FS', 79]], dtype=object),
#  array([['Duke', 'Johnson Jr.', 'Browns', 'HB', 78],
#         ['Isaiah', 'Crowell', 'Browns', 'HB', 76]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Desmond', 'Bryant', 'Browns', 'LE', 77]], dtype=object),
#  array([['Joel', 'Bitonio', 'Browns', 'LG', 83]], dtype=object),
#  array([['Barkevious', 'Mingo', 'Browns', 'LOLB', 76]], dtype=object),
#  array([['Joe', 'Thomas', 'Browns', 'LT', 97]], dtype=object),
#  array([['Demario', 'Davis', 'Browns', 'MLB', 76],
#         ['Christian', 'Kirksey', 'Browns', 'MLB', 74]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Robert', 'Griffin III', 'Browns', 'QB', 73]], dtype=object),
#  array([['John', 'Hughes III', 'Browns', 'RE', 70]], dtype=object),
#  array([['John', 'Greco', 'Browns', 'RG', 77]], dtype=object),
#  array([['Paul', 'Kruger', 'Browns', 'ROLB', 85]], dtype=object),
#  array([['Michael', 'Bowie', 'Browns', 'RT', 72]], dtype=object),
#  array([['Ibraheim', 'Campbell', 'Browns', 'SS', 70]], dtype=object),
#  array([['Gary', 'Barnidge', 'Browns', 'TE', 84]], dtype=object),
#  array([['Corey', 'Coleman', 'Browns', 'WR', 78],
#         ['Josh', 'Gordon', 'Browns', 'WR', 76],
#         ['Andrew', 'Hawkins', 'Browns', 'WR', 73]], dtype=object),
#  array([['Evan', 'Smith', 'Buccaneers', 'C', 75]], dtype=object),
#  array([['Brent', 'Grimes', 'Buccaneers', 'CB', 85],
#         ['Vernon', 'Hargreaves III', 'Buccaneers', 'CB', 77]], dtype=object),
#  array([['Gerald', 'McCoy', 'Buccaneers', 'DT', 92],
#         ['Clinton', 'McDonald', 'Buccaneers', 'DT', 77]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Bradley', 'McDougald', 'Buccaneers', 'FS', 77]], dtype=object),
#  array([['Doug', 'Martin', 'Buccaneers', 'HB', 90],
#         ['Charles', 'Sims III', 'Buccaneers', 'HB', 82]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Robert', 'Ayers Jr.', 'Buccaneers', 'LE', 84]], dtype=object),
#  array([['J.R.', 'Sweezy', 'Buccaneers', 'LG', 76]], dtype=object),
#  array([['Daryl', 'Smith', 'Buccaneers', 'LOLB', 82]], dtype=object),
#  array([['Donovan', 'Smith', 'Buccaneers', 'LT', 77]], dtype=object),
#  array([['Kwon', 'Alexander', 'Buccaneers', 'MLB', 76],
#         ['Adarius', 'Glanton', 'Buccaneers', 'MLB', 61]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Jameis', 'Winston', 'Buccaneers', 'QB', 82]], dtype=object),
#  array([['William', 'Gholston', 'Buccaneers', 'RE', 78]], dtype=object),
#  array([['Ali', 'Marpet', 'Buccaneers', 'RG', 77]], dtype=object),
#  array([['Lavonte', 'David', 'Buccaneers', 'ROLB', 86]], dtype=object),
#  array([['Demar', 'Dotson', 'Buccaneers', 'RT', 78]], dtype=object),
#  array([['Chris', 'Conte', 'Buccaneers', 'SS', 76]], dtype=object),
#  array([['Austin', 'Seferian-Jenkins', 'Buccaneers', 'TE', 78]], dtype=object),
#  array([['Mike', 'Evans', 'Buccaneers', 'WR', 86],
#         ['Vincent', 'Jackson', 'Buccaneers', 'WR', 82],
#         ['Louis', 'Murphy', 'Buccaneers', 'WR', 71]], dtype=object),
#  array([['A.Q.', 'Shipley', 'Cardinals', 'C', 71]], dtype=object),
#  array([['Patrick', 'Peterson', 'Cardinals', 'CB', 91],
#         ['Justin', 'Bethel', 'Cardinals', 'CB', 74]], dtype=object),
#  array([['Corey', 'Peters', 'Cardinals', 'DT', 75],
#         ['Rodney', 'Gunter', 'Cardinals', 'DT', 66]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Tyrann', 'Mathieu', 'Cardinals', 'FS', 96]], dtype=object),
#  array([['David', 'Johnson', 'Cardinals', 'HB', 83],
#         ['Andre', 'Ellington', 'Cardinals', 'HB', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Calais', 'Campbell', 'Cardinals', 'LE', 88]], dtype=object),
#  array([['Mike', 'Iupati', 'Cardinals', 'LG', 86]], dtype=object),
#  array([['Alex', 'Okafor', 'Cardinals', 'LOLB', 71]], dtype=object),
#  array([['Jared', 'Veldheer', 'Cardinals', 'LT', 85]], dtype=object),
#  array([['Deone', 'Bucannon', 'Cardinals', 'MLB', 78],
#         ['Kevin', 'Minter', 'Cardinals', 'MLB', 74]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Carson', 'Palmer', 'Cardinals', 'QB', 89]], dtype=object),
#  array([['Frostee', 'Rucker', 'Cardinals', 'RE', 76]], dtype=object),
#  array([['Evan', 'Mathis', 'Cardinals', 'RG', 88]], dtype=object),
#  array([['Chandler', 'Jones', 'Cardinals', 'ROLB', 82]], dtype=object),
#  array([['D.J.', 'Humphries', 'Cardinals', 'RT', 73]], dtype=object),
#  array([['Tyvon', 'Branch', 'Cardinals', 'SS', 81]], dtype=object),
#  array([['Jermaine', 'Gresham', 'Cardinals', 'TE', 84]], dtype=object),
#  array([['Larry', 'Fitzgerald', 'Cardinals', 'WR', 91],
#         ['John', 'Brown', 'Cardinals', 'WR', 86],
#         ['Michael', 'Floyd', 'Cardinals', 'WR', 85]], dtype=object),
#  array([['Matt', 'Slauson', 'Chargers', 'C', 84]], dtype=object),
#  array([['Jason', 'Verrett', 'Chargers', 'CB', 88],
#         ['Casey', 'Hayward', 'Chargers', 'CB', 84]], dtype=object),
#  array([['Brandon', 'Mebane', 'Chargers', 'DT', 80],
#         ['Sean', 'Lissemore', 'Chargers', 'DT', 72]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Dwight', 'Lowery', 'Chargers', 'FS', 79]], dtype=object),
#  array([['Danny', 'Woodhead', 'Chargers', 'HB', 82],
#         ['Branden', 'Oliver', 'Chargers', 'HB', 79]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Joey', 'Bosa', 'Chargers', 'LE', 79]], dtype=object),
#  array([['Orlando', 'Franklin', 'Chargers', 'LG', 72]], dtype=object),
#  array([['Jeremiah', 'Attaochu', 'Chargers', 'LOLB', 81]], dtype=object),
#  array([['King', 'Dunlap', 'Chargers', 'LT', 82]], dtype=object),
#  array([['Denzel', 'Perryman', 'Chargers', 'MLB', 76],
#         ['Manti', "Te'o", 'Chargers', 'MLB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Philip', 'Rivers', 'Chargers', 'QB', 84]], dtype=object),
#  array([['Corey', 'Liuget', 'Chargers', 'RE', 80]], dtype=object),
#  array([['D.J.', 'Fluker', 'Chargers', 'RG', 74]], dtype=object),
#  array([['Melvin', 'Ingram', 'Chargers', 'ROLB', 86]], dtype=object),
#  array([['Joe', 'Barksdale', 'Chargers', 'RT', 80]], dtype=object),
#  array([['Jahleel', 'Addae', 'Chargers', 'SS', 74]], dtype=object),
#  array([['Antonio', 'Gates', 'Chargers', 'TE', 85]], dtype=object),
#  array([['Keenan', 'Allen', 'Chargers', 'WR', 88],
#         ['Travis', 'Benjamin', 'Chargers', 'WR', 78],
#         ['Stevie', 'Johnson', 'Chargers', 'WR', 77]], dtype=object),
#  array([['Mitch', 'Morse', 'Chiefs', 'C', 73]], dtype=object),
#  array([['Marcus', 'Peters', 'Chiefs', 'CB', 82],
#         ['Phillip', 'Gaines', 'Chiefs', 'CB', 75]], dtype=object),
#  array([['Dontari', 'Poe', 'Chiefs', 'DT', 85],
#         ['Alameda', "Ta'amu", 'Chiefs', 'DT', 71]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Eric', 'Berry', 'Chiefs', 'FS', 93]], dtype=object),
#  array([['Jamaal', 'Charles', 'Chiefs', 'HB', 89],
#         ['Charcandrick', 'West', 'Chiefs', 'HB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Jaye', 'Howard', 'Chiefs', 'LE', 83]], dtype=object),
#  array([['Parker', 'Ehinger', 'Chiefs', 'LG', 66]], dtype=object),
#  array([['Justin', 'Houston', 'Chiefs', 'LOLB', 97]], dtype=object),
#  array([['Eric', 'Fisher', 'Chiefs', 'LT', 78]], dtype=object),
#  array([['Derrick', 'Johnson', 'Chiefs', 'MLB', 90],
#         ['Josh', 'Mauga', 'Chiefs', 'MLB', 77]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Alex', 'Smith', 'Chiefs', 'QB', 82]], dtype=object),
#  array([['Allen', 'Bailey', 'Chiefs', 'RE', 79]], dtype=object),
#  array([['Laurent', 'Duvernay-Tardif', 'Chiefs', 'RG', 73]], dtype=object),
#  array([['Tamba', 'Hali', 'Chiefs', 'ROLB', 90]], dtype=object),
#  array([['Mitchell', 'Schwartz', 'Chiefs', 'RT', 86]], dtype=object),
#  array([['Ron', 'Parker', 'Chiefs', 'SS', 81]], dtype=object),
#  array([['Travis', 'Kelce', 'Chiefs', 'TE', 88]], dtype=object),
#  array([['Jeremy', 'Maclin', 'Chiefs', 'WR', 86],
#         ['Albert', 'Wilson', 'Chiefs', 'WR', 74],
#         ['Rod', 'Streater', 'Chiefs', 'WR', 72]], dtype=object),
#  array([['Ryan', 'Kelly', 'Colts', 'C', 76]], dtype=object),
#  array([['Vontae', 'Davis', 'Colts', 'CB', 91],
#         ['Patrick', 'Robinson', 'Colts', 'CB', 78]], dtype=object),
#  array([['Zach', 'Kerr', 'Colts', 'DT', 73],
#         ['David', 'Parry', 'Colts', 'DT', 68]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['T.J.', 'Green', 'Colts', 'FS', 71]], dtype=object),
#  array([['Frank', 'Gore', 'Colts', 'HB', 79],
#         ['Robert', 'Turbin', 'Colts', 'HB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Kendall', 'Langford', 'Colts', 'LE', 80]], dtype=object),
#  array([['Jack', 'Mewhort', 'Colts', 'LG', 85]], dtype=object),
#  array([['Erik', 'Walden', 'Colts', 'LOLB', 78]], dtype=object),
#  array([['Anthony', 'Castonzo', 'Colts', 'LT', 81]], dtype=object),
#  array([["D'Qwell", 'Jackson', 'Colts', 'MLB', 79],
#         ['Nate', 'Irving', 'Colts', 'MLB', 76]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Andrew', 'Luck', 'Colts', 'QB', 88]], dtype=object),
#  array([['Arthur', 'Jones', 'Colts', 'RE', 71]], dtype=object),
#  array([['Jonotthan', 'Harrison', 'Colts', 'RG', 73]], dtype=object),
#  array([['Robert', 'Mathis', 'Colts', 'ROLB', 83]], dtype=object),
#  array([['Joe', 'Reitz', 'Colts', 'RT', 79]], dtype=object),
#  array([['Mike', 'Adams', 'Colts', 'SS', 78]], dtype=object),
#  array([['Dwayne', 'Allen', 'Colts', 'TE', 80]], dtype=object),
#  array([['T.Y.', 'Hilton', 'Colts', 'WR', 89],
#         ['Donte', 'Moncrief', 'Colts', 'WR', 78],
#         ['Phillip', 'Dorsett', 'Colts', 'WR', 72]], dtype=object),
#  array([['Travis', 'Frederick', 'Cowboys', 'C', 91]], dtype=object),
#  array([['Orlando', 'Scandrick', 'Cowboys', 'CB', 87],
#         ['Brandon', 'Carr', 'Cowboys', 'CB', 76]], dtype=object),
#  array([['Tyrone', 'Crawford', 'Cowboys', 'DT', 80],
#         ['Cedric', 'Thornton', 'Cowboys', 'DT', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Byron', 'Jones', 'Cowboys', 'FS', 81]], dtype=object),
#  array([['Ezekiel', 'Elliott', 'Cowboys', 'HB', 80],
#         ['Darren', 'McFadden', 'Cowboys', 'HB', 79]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['DeMarcus', 'Lawrence', 'Cowboys', 'LE', 81]], dtype=object),
#  array([["La'el", 'Collins', 'Cowboys', 'LG', 78]], dtype=object),
#  array([['Justin', 'Durant', 'Cowboys', 'LOLB', 77]], dtype=object),
#  array([['Tyron', 'Smith', 'Cowboys', 'LT', 97]], dtype=object),
#  array([['Rolando', 'McClain', 'Cowboys', 'MLB', 81],
#         ['Jaylon', 'Smith', 'Cowboys', 'MLB', 76]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Tony', 'Romo', 'Cowboys', 'QB', 86]], dtype=object),
#  array([['Randy', 'Gregory', 'Cowboys', 'RE', 75]], dtype=object),
#  array([['Zack', 'Martin', 'Cowboys', 'RG', 92]], dtype=object),
#  array([['Sean', 'Lee', 'Cowboys', 'ROLB', 89]], dtype=object),
#  array([['Doug', 'Free', 'Cowboys', 'RT', 80]], dtype=object),
#  array([['Barry', 'Church', 'Cowboys', 'SS', 82]], dtype=object),
#  array([['Jason', 'Witten', 'Cowboys', 'TE', 87]], dtype=object),
#  array([['Dez', 'Bryant', 'Cowboys', 'WR', 90],
#         ['Terrance', 'Williams', 'Cowboys', 'WR', 80],
#         ['Cole', 'Beasley', 'Cowboys', 'WR', 77]], dtype=object),
#  array([['Mike', 'Pouncey', 'Dolphins', 'C', 81]], dtype=object),
#  array([['Byron', 'Maxwell', 'Dolphins', 'CB', 76],
#         ['Xavien', 'Howard', 'Dolphins', 'CB', 72]], dtype=object),
#  array([['Ndamukong', 'Suh', 'Dolphins', 'DT', 93],
#         ['Earl', 'Mitchell', 'Dolphins', 'DT', 74]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Isa', 'Abdul-Quddus', 'Dolphins', 'FS', 76]], dtype=object),
#  array([['Arian', 'Foster', 'Dolphins', 'HB', 81],
#         ['Jay', 'Ajayi', 'Dolphins', 'HB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Cameron', 'Wake', 'Dolphins', 'LE', 89]], dtype=object),
#  array([['Jermon', 'Bushrod', 'Dolphins', 'LG', 81]], dtype=object),
#  array([['Koa', 'Misi', 'Dolphins', 'LOLB', 85]], dtype=object),
#  array([['Branden', 'Albert', 'Dolphins', 'LT', 80]], dtype=object),
#  array([['Kiko', 'Alonso', 'Dolphins', 'MLB', 76],
#         ['Mike', 'Hull', 'Dolphins', 'MLB', 61]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Ryan', 'Tannehill', 'Dolphins', 'QB', 79]], dtype=object),
#  array([['Mario', 'Williams', 'Dolphins', 'RE', 81]], dtype=object),
#  array([['Kraig', 'Urbik', 'Dolphins', 'RG', 72]], dtype=object),
#  array([['Jelani', 'Jenkins', 'Dolphins', 'ROLB', 78]], dtype=object),
#  array([["Ja'Wuan", 'James', 'Dolphins', 'RT', 75]], dtype=object),
#  array([['Reshad', 'Jones', 'Dolphins', 'SS', 93]], dtype=object),
#  array([['Jordan', 'Cameron', 'Dolphins', 'TE', 81]], dtype=object),
#  array([['Jarvis', 'Landry', 'Dolphins', 'WR', 87],
#         ['DeVante', 'Parker', 'Dolphins', 'WR', 77],
#         ['Kenny', 'Stills', 'Dolphins', 'WR', 74]], dtype=object),
#  array([['Jason', 'Kelce', 'Eagles', 'C', 85]], dtype=object),
#  array([['Nolan', 'Carroll II', 'Eagles', 'CB', 76],
#         ['Eric', 'Rowe', 'Eagles', 'CB', 74]], dtype=object),
#  array([['Fletcher', 'Cox', 'Eagles', 'DT', 93],
#         ['Bennie', 'Logan', 'Eagles', 'DT', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Malcolm', 'Jenkins', 'Eagles', 'FS', 93]], dtype=object),
#  array([['Ryan', 'Mathews', 'Eagles', 'HB', 82],
#         ['Darren', 'Sproles', 'Eagles', 'HB', 81]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Connor', 'Barwin', 'Eagles', 'LE', 84]], dtype=object),
#  array([['Barrett', 'Jones', 'Eagles', 'LG', 72]], dtype=object),
#  array([['Mychal', 'Kendricks', 'Eagles', 'LOLB', 85]], dtype=object),
#  array([['Jason', 'Peters', 'Eagles', 'LT', 87]], dtype=object),
#  array([['Jordan', 'Hicks', 'Eagles', 'MLB', 74],
#         ['Najee', 'Goode', 'Eagles', 'MLB', 64]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Sam', 'Bradford', 'Eagles', 'QB', 78]], dtype=object),
#  array([['Brandon', 'Graham', 'Eagles', 'RE', 92]], dtype=object),
#  array([['Brandon', 'Brooks', 'Eagles', 'RG', 80]], dtype=object),
#  array([['Nigel', 'Bradham', 'Eagles', 'ROLB', 76]], dtype=object),
#  array([['Lane', 'Johnson', 'Eagles', 'RT', 86]], dtype=object),
#  array([['Rodney', 'McLeod Jr.', 'Eagles', 'SS', 81]], dtype=object),
#  array([['Zach', 'Ertz', 'Eagles', 'TE', 87]], dtype=object),
#  array([['Rueben', 'Randle', 'Eagles', 'WR', 78],
#         ['Jordan', 'Matthews', 'Eagles', 'WR', 78],
#         ['Nelson', 'Agholor', 'Eagles', 'WR', 72]], dtype=object),
#  array([['Alex', 'Mack', 'Falcons', 'C', 84]], dtype=object),
#  array([['Desmond', 'Trufant', 'Falcons', 'CB', 90],
#         ['Robert', 'Alford', 'Falcons', 'CB', 77]], dtype=object),
#  array([['Jonathan', 'Babineaux', 'Falcons', 'DT', 81],
#         ['Tyson', 'Jackson', 'Falcons', 'DT', 77]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Ricardo', 'Allen', 'Falcons', 'FS', 75]], dtype=object),
#  array([['Devonta', 'Freeman', 'Falcons', 'HB', 86],
#         ['Tevin', 'Coleman', 'Falcons', 'HB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Adrian', 'Clayborn', 'Falcons', 'LE', 77]], dtype=object),
#  array([['Andy', 'Levitre', 'Falcons', 'LG', 80]], dtype=object),
#  array([['Courtney', 'Upshaw', 'Falcons', 'LOLB', 78]], dtype=object),
#  array([['Jake', 'Matthews', 'Falcons', 'LT', 80]], dtype=object),
#  array([['Paul', 'Worrilow', 'Falcons', 'MLB', 74],
#         ['Sean', 'Weatherspoon', 'Falcons', 'MLB', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Matt', 'Ryan', 'Falcons', 'QB', 84]], dtype=object),
#  array([["Ra'Shede", 'Hageman', 'Falcons', 'RE', 74]], dtype=object),
#  array([['Chris', 'Chester', 'Falcons', 'RG', 78]], dtype=object),
#  array([['Vic', 'Beasley Jr.', 'Falcons', 'ROLB', 79]], dtype=object),
#  array([['Ryan', 'Schraeder', 'Falcons', 'RT', 85]], dtype=object),
#  array([['Keanu', 'Neal', 'Falcons', 'SS', 77]], dtype=object),
#  array([['Jacob', 'Tamme', 'Falcons', 'TE', 79]], dtype=object),
#  array([['Julio', 'Jones', 'Falcons', 'WR', 96],
#         ['Mohamed', 'Sanu Sr.', 'Falcons', 'WR', 77],
#         ['Nick', 'Williams', 'Falcons', 'WR', 69]], dtype=object),
#  array([['Weston', 'Richburg', 'Giants', 'C', 88]], dtype=object),
#  array([['Dominique', 'Rodgers-Cromartie', 'Giants', 'CB', 87],
#         ['Janoris', 'Jenkins', 'Giants', 'CB', 85]], dtype=object),
#  array([['Damon', 'Harrison', 'Giants', 'DT', 84],
#         ['Johnathan', 'Hankins', 'Giants', 'DT', 81]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Landon', 'Collins', 'Giants', 'FS', 75]], dtype=object),
#  array([['Shane', 'Vereen', 'Giants', 'HB', 81],
#         ['Rashad', 'Jennings', 'Giants', 'HB', 80]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Jason', 'Pierre-Paul', 'Giants', 'LE', 85]], dtype=object),
#  array([['Justin', 'Pugh', 'Giants', 'LG', 84]], dtype=object),
#  array([['Devon', 'Kennard', 'Giants', 'LOLB', 78]], dtype=object),
#  array([['Ereck', 'Flowers', 'Giants', 'LT', 76]], dtype=object),
#  array([['Keenan', 'Robinson', 'Giants', 'MLB', 75],
#         ['Jasper', 'Brinkley', 'Giants', 'MLB', 72]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Eli', 'Manning', 'Giants', 'QB', 81]], dtype=object),
#  array([['Olivier', 'Vernon', 'Giants', 'RE', 91]], dtype=object),
#  array([['John', 'Jerry', 'Giants', 'RG', 73]], dtype=object),
#  array([['J.T.', 'Thomas III', 'Giants', 'ROLB', 76]], dtype=object),
#  array([['Marshall', 'Newhouse', 'Giants', 'RT', 70]], dtype=object),
#  array([['Cooper', 'Taylor', 'Giants', 'SS', 69]], dtype=object),
#  array([['Larry', 'Donnell', 'Giants', 'TE', 76]], dtype=object),
#  array([['Odell', 'Beckham Jr.', 'Giants', 'WR', 93],
#         ['Victor', 'Cruz', 'Giants', 'WR', 81],
#         ['Sterling', 'Shepard', 'Giants', 'WR', 74]], dtype=object),
#  array([['Luke', 'Bowanko', 'Jaguars', 'C', 76]], dtype=object),
#  array([['Prince', 'Amukamara', 'Jaguars', 'CB', 83],
#         ['Jalen', 'Ramsey', 'Jaguars', 'CB', 82]], dtype=object),
#  array([["Sen'Derrick", 'Marks', 'Jaguars', 'DT', 79],
#         ['Roy', 'Miller III', 'Jaguars', 'DT', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Tashaun', 'Gipson', 'Jaguars', 'FS', 77]], dtype=object),
#  array([['Chris', 'Ivory', 'Jaguars', 'HB', 82],
#         ['T.J.', 'Yeldon', 'Jaguars', 'HB', 80]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Malik', 'Jackson', 'Jaguars', 'LE', 86]], dtype=object),
#  array([['Mackenzy', 'Bernadeau', 'Jaguars', 'LG', 74]], dtype=object),
#  array([['Telvin', 'Smith', 'Jaguars', 'LOLB', 80]], dtype=object),
#  array([['Kelvin', 'Beachum', 'Jaguars', 'LT', 82]], dtype=object),
#  array([['Paul', 'Posluszny', 'Jaguars', 'MLB', 78],
#         ['Joplo', 'Bartu', 'Jaguars', 'MLB', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Blake', 'Bortles', 'Jaguars', 'QB', 82]], dtype=object),
#  array([['Jared', 'Odrick', 'Jaguars', 'RE', 78]], dtype=object),
#  array([['Brandon', 'Linder', 'Jaguars', 'RG', 77]], dtype=object),
#  array([['Dan', 'Skuta', 'Jaguars', 'ROLB', 79]], dtype=object),
#  array([['Jermey', 'Parnell', 'Jaguars', 'RT', 77]], dtype=object),
#  array([['Johnathan', 'Cyprien', 'Jaguars', 'SS', 76]], dtype=object),
#  array([['Julius', 'Thomas', 'Jaguars', 'TE', 83]], dtype=object),
#  array([['Allen', 'Robinson', 'Jaguars', 'WR', 88],
#         ['Allen', 'Hurns', 'Jaguars', 'WR', 85],
#         ['Marqise', 'Lee', 'Jaguars', 'WR', 71]], dtype=object),
#  array([['Nick', 'Mangold', 'Jets', 'C', 83]], dtype=object),
#  array([['Darrelle', 'Revis', 'Jets', 'CB', 91],
#         ['Buster', 'Skrine', 'Jets', 'CB', 75]], dtype=object),
#  array([['Steve', 'McLendon', 'Jets', 'DT', 78],
#         ['Tarow', 'Barney', 'Jets', 'DT', 62]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Marcus', 'Gilchrist', 'Jets', 'FS', 82]], dtype=object),
#  array([['Matt', 'Forte', 'Jets', 'HB', 86],
#         ['Bilal', 'Powell', 'Jets', 'HB', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Muhammad', 'Wilkerson', 'Jets', 'LE', 89]], dtype=object),
#  array([['James', 'Carpenter', 'Jets', 'LG', 79]], dtype=object),
#  array([['Jordan', 'Jenkins', 'Jets', 'LOLB', 69]], dtype=object),
#  array([['Ryan', 'Clady', 'Jets', 'LT', 84]], dtype=object),
#  array([['David', 'Harris', 'Jets', 'MLB', 81],
#         ['Erin', 'Henderson', 'Jets', 'MLB', 75]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Ryan', 'Fitzpatrick', 'Jets', 'QB', 79]], dtype=object),
#  array([['Sheldon', 'Richardson', 'Jets', 'RE', 86]], dtype=object),
#  array([['Brian', 'Winters', 'Jets', 'RG', 70]], dtype=object),
#  array([['Lorenzo', 'Mauldin IV', 'Jets', 'ROLB', 70]], dtype=object),
#  array([['Breno', 'Giacomini', 'Jets', 'RT', 69]], dtype=object),
#  array([['Calvin', 'Pryor III', 'Jets', 'SS', 83]], dtype=object),
#  array([['Jace', 'Amaro', 'Jets', 'TE', 74]], dtype=object),
#  array([['Brandon', 'Marshall', 'Jets', 'WR', 89],
#         ['Eric', 'Decker', 'Jets', 'WR', 87],
#         ['Devin', 'Smith', 'Jets', 'WR', 70]], dtype=object),
#  array([['Graham', 'Glasgow', 'Lions', 'C', 69]], dtype=object),
#  array([['Darius', 'Slay', 'Lions', 'CB', 90],
#         ['Quandre', 'Diggs', 'Lions', 'CB', 74]], dtype=object),
#  array([['Haloti', 'Ngata', 'Lions', 'DT', 82],
#         ['Tyrunn', 'Walker', 'Lions', 'DT', 72]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Glover', 'Quin', 'Lions', 'FS', 83]], dtype=object),
#  array([['Theo', 'Riddick', 'Lions', 'HB', 81],
#         ['Ameer', 'Abdullah', 'Lions', 'HB', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Wallace', 'Gilberry', 'Lions', 'LE', 74]], dtype=object),
#  array([['Laken', 'Tomlinson', 'Lions', 'LG', 69]], dtype=object),
#  array([['Tahir', 'Whitehead', 'Lions', 'LOLB', 83]], dtype=object),
#  array([['Taylor', 'Decker', 'Lions', 'LT', 76]], dtype=object),
#  array([['Jon', 'Bostic', 'Lions', 'MLB', 68],
#         ['Zaviar', 'Gooden', 'Lions', 'MLB', 67]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Matthew', 'Stafford', 'Lions', 'QB', 85]], dtype=object),
#  array([['Ezekiel', 'Ansah', 'Lions', 'RE', 90]], dtype=object),
#  array([['Geoff', 'Schwartz', 'Lions', 'RG', 81]], dtype=object),
#  array([['DeAndre', 'Levy', 'Lions', 'ROLB', 87]], dtype=object),
#  array([['Riley', 'Reiff', 'Lions', 'RT', 83]], dtype=object),
#  array([['Tavon', 'Wilson', 'Lions', 'SS', 73]], dtype=object),
#  array([['Eric', 'Ebron', 'Lions', 'TE', 76]], dtype=object),
#  array([['Golden', 'Tate III', 'Lions', 'WR', 89],
#         ['Marvin', 'Jones', 'Lions', 'WR', 82],
#         ['Anquan', 'Boldin', 'Lions', 'WR', 79]], dtype=object),
#  array([['Corey', 'Linsley', 'Packers', 'C', 80]], dtype=object),
#  array([['Sam', 'Shields', 'Packers', 'CB', 86],
#         ['Damarious', 'Randall', 'Packers', 'CB', 76]], dtype=object),
#  array([['Letroy', 'Guion', 'Packers', 'DT', 73],
#         ['Kenny', 'Clark', 'Packers', 'DT', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Ha Ha', 'Clinton-Dix', 'Packers', 'FS', 83]], dtype=object),
#  array([['Eddie', 'Lacy', 'Packers', 'HB', 83],
#         ['James', 'Starks', 'Packers', 'HB', 79]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Datone', 'Jones', 'Packers', 'LE', 76]], dtype=object),
#  array([['Josh', 'Sitton', 'Packers', 'LG', 91]], dtype=object),
#  array([['Clay', 'Matthews', 'Packers', 'LOLB', 89]], dtype=object),
#  array([['David', 'Bakhtiari', 'Packers', 'LT', 79]], dtype=object),
#  array([['Sam', 'Barrington', 'Packers', 'MLB', 73],
#         ['Joe', 'Thomas', 'Packers', 'MLB', 70]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Aaron', 'Rodgers', 'Packers', 'QB', 96]], dtype=object),
#  array([['Mike', 'Daniels', 'Packers', 'RE', 92]], dtype=object),
#  array([['T.J.', 'Lang', 'Packers', 'RG', 91]], dtype=object),
#  array([['Julius', 'Peppers', 'Packers', 'ROLB', 86]], dtype=object),
#  array([['Bryan', 'Bulaga', 'Packers', 'RT', 79]], dtype=object),
#  array([['Morgan', 'Burnett', 'Packers', 'SS', 85]], dtype=object),
#  array([['Jared', 'Cook', 'Packers', 'TE', 80]], dtype=object),
#  array([['Jordy', 'Nelson', 'Packers', 'WR', 89],
#         ['Randall', 'Cobb', 'Packers', 'WR', 86],
#         ['Davante', 'Adams', 'Packers', 'WR', 75]], dtype=object),
#  array([['Ryan', 'Kalil', 'Panthers', 'C', 89]], dtype=object),
#  array([['Bene', 'Benwikere', 'Panthers', 'CB', 80],
#         ['Leonard', 'Johnson', 'Panthers', 'CB', 71]], dtype=object),
#  array([['Kawann', 'Short', 'Panthers', 'DT', 92],
#         ['Paul', 'Soliai', 'Panthers', 'DT', 80]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Kurt', 'Coleman', 'Panthers', 'FS', 87]], dtype=object),
#  array([['Jonathan', 'Stewart', 'Panthers', 'HB', 87],
#         ['Cameron', 'Artis-Payne', 'Panthers', 'HB', 70]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Charles', 'Johnson', 'Panthers', 'LE', 82]], dtype=object),
#  array([['Andrew', 'Norwell', 'Panthers', 'LG', 83]], dtype=object),
#  array([['Shaq', 'Thompson', 'Panthers', 'LOLB', 75]], dtype=object),
#  array([['Michael', 'Oher', 'Panthers', 'LT', 78]], dtype=object),
#  array([['Luke', 'Kuechly', 'Panthers', 'MLB', 99],
#         ['David', 'Mayo', 'Panthers', 'MLB', 64]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Cam', 'Newton', 'Panthers', 'QB', 94]], dtype=object),
#  array([['Kony', 'Ealy', 'Panthers', 'RE', 79]], dtype=object),
#  array([['Trai', 'Turner', 'Panthers', 'RG', 87]], dtype=object),
#  array([['Thomas', 'Davis Sr.', 'Panthers', 'ROLB', 88]], dtype=object),
#  array([['Mike', 'Remmers', 'Panthers', 'RT', 76]], dtype=object),
#  array([['Tre', 'Boston', 'Panthers', 'SS', 78]], dtype=object),
#  array([['Greg', 'Olsen', 'Panthers', 'TE', 93]], dtype=object),
#  array([['Kelvin', 'Benjamin', 'Panthers', 'WR', 83],
#         ['Ted', 'Ginn Jr.', 'Panthers', 'WR', 77],
#         ['Philly', 'Brown', 'Panthers', 'WR', 76]], dtype=object),
#  array([['Bryan', 'Stork', 'Patriots', 'C', 73]], dtype=object),
#  array([['Malcolm', 'Butler', 'Patriots', 'CB', 85],
#         ['Logan', 'Ryan', 'Patriots', 'CB', 84]], dtype=object),
#  array([['Terrance', 'Knighton', 'Patriots', 'DT', 83],
#         ['Alan', 'Branch', 'Patriots', 'DT', 77]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Devin', 'McCourty', 'Patriots', 'FS', 91]], dtype=object),
#  array([['LeGarrette', 'Blount', 'Patriots', 'HB', 81],
#         ['Dion', 'Lewis', 'Patriots', 'HB', 80]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Chris', 'Long', 'Patriots', 'LE', 77]], dtype=object),
#  array([['Shaq', 'Mason', 'Patriots', 'LG', 74]], dtype=object),
#  array([['Rob', 'Ninkovich', 'Patriots', 'LOLB', 82]], dtype=object),
#  array([['Nate', 'Solder', 'Patriots', 'LT', 84]], dtype=object),
#  array([['Jamie', 'Collins', 'Patriots', 'MLB', 88],
#         ['Jonathan', 'Freeny', 'Patriots', 'MLB', 69]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Tom', 'Brady', 'Patriots', 'QB', 94]], dtype=object),
#  array([['Jabaal', 'Sheard', 'Patriots', 'RE', 88]], dtype=object),
#  array([['Jonathan', 'Cooper', 'Patriots', 'RG', 76]], dtype=object),
#  array([["Dont'a", 'Hightower', 'Patriots', 'ROLB', 90]], dtype=object),
#  array([['Sebastian', 'Vollmer', 'Patriots', 'RT', 84]], dtype=object),
#  array([['Patrick', 'Chung', 'Patriots', 'SS', 86]], dtype=object),
#  array([['Rob', 'Gronkowski', 'Patriots', 'TE', 99]], dtype=object),
#  array([['Julian', 'Edelman', 'Patriots', 'WR', 89],
#         ['Danny', 'Amendola', 'Patriots', 'WR', 83],
#         ['Chris', 'Hogan', 'Patriots', 'WR', 75]], dtype=object),
#  array([['Rodney', 'Hudson', 'Raiders', 'C', 85]], dtype=object),
#  array([['Sean', 'Smith', 'Raiders', 'CB', 88],
#         ['David', 'Amerson', 'Raiders', 'CB', 84]], dtype=object),
#  array([['Dan', 'Williams', 'Raiders', 'DT', 88],
#         ['Justin', 'Ellis', 'Raiders', 'DT', 71]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Reggie', 'Nelson', 'Raiders', 'FS', 87]], dtype=object),
#  array([['Latavius', 'Murray', 'Raiders', 'HB', 81],
#         ['Taiwan', 'Jones', 'Raiders', 'HB', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Jihad', 'Ward', 'Raiders', 'LE', 71]], dtype=object),
#  array([['Gabe', 'Jackson', 'Raiders', 'LG', 83]], dtype=object),
#  array([['Khalil', 'Mack', 'Raiders', 'LOLB', 94]], dtype=object),
#  array([['Donald', 'Penn', 'Raiders', 'LT', 87]], dtype=object),
#  array([['Malcolm', 'Smith', 'Raiders', 'MLB', 71],
#         ['Ben', 'Heeney', 'Raiders', 'MLB', 70]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Derek', 'Carr', 'Raiders', 'QB', 83]], dtype=object),
#  array([['Mario', 'Edwards Jr.', 'Raiders', 'RE', 78]], dtype=object),
#  array([['Kelechi', 'Osemele', 'Raiders', 'RG', 89]], dtype=object),
#  array([['Aldon', 'Smith', 'Raiders', 'ROLB', 85]], dtype=object),
#  array([['Austin', 'Howard', 'Raiders', 'RT', 80]], dtype=object),
#  array([['Nate', 'Allen', 'Raiders', 'SS', 77]], dtype=object),
#  array([['Clive', 'Walford', 'Raiders', 'TE', 77]], dtype=object),
#  array([['Amari', 'Cooper', 'Raiders', 'WR', 83],
#         ['Michael', 'Crabtree', 'Raiders', 'WR', 83],
#         ['Andre', 'Holmes', 'Raiders', 'WR', 73]], dtype=object),
#  array([['Tim', 'Barnes', 'Rams', 'C', 69]], dtype=object),
#  array([['Trumaine', 'Johnson', 'Rams', 'CB', 80],
#         ['E.J.', 'Gaines', 'Rams', 'CB', 79]], dtype=object),
#  array([['Aaron', 'Donald', 'Rams', 'DT', 98],
#         ['Michael', 'Brockers', 'Rams', 'DT', 79]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Cody', 'Davis', 'Rams', 'FS', 68]], dtype=object),
#  array([['Todd', 'Gurley II', 'Rams', 'HB', 85],
#         ['Tre', 'Mason', 'Rams', 'HB', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['William', 'Hayes', 'Rams', 'LE', 85]], dtype=object),
#  array([['Garrett', 'Reynolds', 'Rams', 'LG', 78]], dtype=object),
#  array([['Mark', 'Barron', 'Rams', 'LOLB', 75]], dtype=object),
#  array([['Greg', 'Robinson', 'Rams', 'LT', 77]], dtype=object),
#  array([['Alec', 'Ogletree', 'Rams', 'MLB', 79],
#         ['Brandon', 'Chubb', 'Rams', 'MLB', 60]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Jared', 'Goff', 'Rams', 'QB', 77]], dtype=object),
#  array([['Robert', 'Quinn', 'Rams', 'RE', 89]], dtype=object),
#  array([['Jamon', 'Brown', 'Rams', 'RG', 68]], dtype=object),
#  array([['Akeem', 'Ayers', 'Rams', 'ROLB', 77]], dtype=object),
#  array([['Rob', 'Havenstein', 'Rams', 'RT', 72]], dtype=object),
#  array([['T.J.', 'McDonald Jr.', 'Rams', 'SS', 83]], dtype=object),
#  array([['Lance', 'Kendricks', 'Rams', 'TE', 75]], dtype=object),
#  array([['Kenny', 'Britt', 'Rams', 'WR', 80],
#         ['Tavon', 'Austin', 'Rams', 'WR', 80],
#         ['Brian', 'Quick', 'Rams', 'WR', 74]], dtype=object),
#  array([['Jeremy', 'Zuttah', 'Ravens', 'C', 81]], dtype=object),
#  array([['Jimmy', 'Smith', 'Ravens', 'CB', 81],
#         ['Lardarius', 'Webb', 'Ravens', 'CB', 79]], dtype=object),
#  array([['Brandon', 'Williams', 'Ravens', 'DT', 84],
#         ['Willie', 'Henry', 'Ravens', 'DT', 68]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Eric', 'Weddle', 'Ravens', 'FS', 92]], dtype=object),
#  array([['Justin', 'Forsett', 'Ravens', 'HB', 82],
#         ['Javorius', 'Allen', 'Ravens', 'HB', 74]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Timmy', 'Jernigan', 'Ravens', 'LE', 76]], dtype=object),
#  array([['John', 'Urschel', 'Ravens', 'LG', 70]], dtype=object),
#  array([['Elvis', 'Dumervil', 'Ravens', 'LOLB', 87]], dtype=object),
#  array([['Ronnie', 'Stanley', 'Ravens', 'LT', 79]], dtype=object),
#  array([['C.J.', 'Mosley', 'Ravens', 'MLB', 83],
#         ['Kavell', 'Conner', 'Ravens', 'MLB', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Joe', 'Flacco', 'Ravens', 'QB', 81]], dtype=object),
#  array([['Lawrence', 'Guy', 'Ravens', 'RE', 71]], dtype=object),
#  array([['Marshal', 'Yanda', 'Ravens', 'RG', 97]], dtype=object),
#  array([['Terrell', 'Suggs', 'Ravens', 'ROLB', 90]], dtype=object),
#  array([['Rick', 'Wagner', 'Ravens', 'RT', 76]], dtype=object),
#  array([['Matt', 'Elam', 'Ravens', 'SS', 69]], dtype=object),
#  array([['Benjamin', 'Watson', 'Ravens', 'TE', 81]], dtype=object),
#  array([['Steve', 'Smith Sr.', 'Ravens', 'WR', 89],
#         ['Kamar', 'Aiken', 'Ravens', 'WR', 78],
#         ['Mike', 'Wallace', 'Ravens', 'WR', 77]], dtype=object),
#  array([['Kory', 'Lichtensteiger', 'Redskins', 'C', 71]], dtype=object),
#  array([['Josh', 'Norman', 'Redskins', 'CB', 94],
#         ['Bashaud', 'Breeland', 'Redskins', 'CB', 81]], dtype=object),
#  array([['Kedric', 'Golston', 'Redskins', 'DT', 71],
#         ['Ziggy', 'Hood', 'Redskins', 'DT', 70]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['DeAngelo', 'Hall', 'Redskins', 'FS', 82]], dtype=object),
#  array([['Matt', 'Jones', 'Redskins', 'HB', 77],
#         ['Chris', 'Thompson', 'Redskins', 'HB', 72]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Chris', 'Baker', 'Redskins', 'LE', 81]], dtype=object),
#  array([['Shawn', 'Lauvao', 'Redskins', 'LG', 74]], dtype=object),
#  array([['Ryan', 'Kerrigan', 'Redskins', 'LOLB', 88]], dtype=object),
#  array([['Trent', 'Williams', 'Redskins', 'LT', 92]], dtype=object),
#  array([['Perry', 'Riley Jr.', 'Redskins', 'MLB', 74],
#         ['Mason', 'Foster', 'Redskins', 'MLB', 72]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Kirk', 'Cousins', 'Redskins', 'QB', 83]], dtype=object),
#  array([['Trent', 'Murphy', 'Redskins', 'RE', 81]], dtype=object),
#  array([['Brandon', 'Scherff', 'Redskins', 'RG', 78]], dtype=object),
#  array([['Preston', 'Smith', 'Redskins', 'ROLB', 77]], dtype=object),
#  array([['Morgan', 'Moses', 'Redskins', 'RT', 78]], dtype=object),
#  array([['David', 'Bruton Jr.', 'Redskins', 'SS', 77]], dtype=object),
#  array([['Jordan', 'Reed', 'Redskins', 'TE', 89]], dtype=object),
#  array([['DeSean', 'Jackson', 'Redskins', 'WR', 84],
#         ['Pierre', 'Garcon', 'Redskins', 'WR', 81],
#         ['Josh', 'Doctson', 'Redskins', 'WR', 77]], dtype=object),
#  array([['Max', 'Unger', 'Saints', 'C', 82]], dtype=object),
#  array([['Delvin', 'Breaux', 'Saints', 'CB', 82],
#         ['Keenan', 'Lewis', 'Saints', 'CB', 75]], dtype=object),
#  array([['Nick', 'Fairley', 'Saints', 'DT', 79],
#         ['John', 'Jenkins', 'Saints', 'DT', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Jairus', 'Byrd', 'Saints', 'FS', 83]], dtype=object),
#  array([['Mark', 'Ingram', 'Saints', 'HB', 83],
#         ['C.J.', 'Spiller', 'Saints', 'HB', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Cameron', 'Jordan', 'Saints', 'LE', 90]], dtype=object),
#  array([['Tim', 'Lelito', 'Saints', 'LG', 77]], dtype=object),
#  array([['Stephone', 'Anthony', 'Saints', 'LOLB', 74]], dtype=object),
#  array([['Terron', 'Armstead', 'Saints', 'LT', 92]], dtype=object),
#  array([['James', 'Laurinaitis', 'Saints', 'MLB', 73],
#         ['Nathan', 'Stupar', 'Saints', 'MLB', 71]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Drew', 'Brees', 'Saints', 'QB', 90]], dtype=object),
#  array([["Hau'oli", 'Kikaha', 'Saints', 'RE', 75]], dtype=object),
#  array([['Senio', 'Kelemete', 'Saints', 'RG', 71]], dtype=object),
#  array([['Craig', 'Robertson', 'Saints', 'ROLB', 78]], dtype=object),
#  array([['Zach', 'Strief', 'Saints', 'RT', 82]], dtype=object),
#  array([['Kenny', 'Vaccaro', 'Saints', 'SS', 80]], dtype=object),
#  array([['Coby', 'Fleener', 'Saints', 'TE', 84]], dtype=object),
#  array([['Brandin', 'Cooks', 'Saints', 'WR', 83],
#         ['Willie', 'Snead', 'Saints', 'WR', 77],
#         ['Hakeem', 'Nicks', 'Saints', 'WR', 73]], dtype=object),
#  array([['Justin', 'Britt', 'Seahawks', 'C', 71]], dtype=object),
#  array([['Richard', 'Sherman', 'Seahawks', 'CB', 92],
#         ['Jeremy', 'Lane', 'Seahawks', 'CB', 77]], dtype=object),
#  array([['Ahtyba', 'Rubin', 'Seahawks', 'DT', 74],
#         ['Sealver', 'Siliga', 'Seahawks', 'DT', 73]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Earl', 'Thomas III', 'Seahawks', 'FS', 93]], dtype=object),
#  array([['Thomas', 'Rawls', 'Seahawks', 'HB', 80],
#         ['C.J.', 'Prosise', 'Seahawks', 'HB', 74]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Michael', 'Bennett', 'Seahawks', 'LE', 91]], dtype=object),
#  array([['Mark', 'Glowinski', 'Seahawks', 'LG', 69]], dtype=object),
#  array([['Mike', 'Morgan', 'Seahawks', 'LOLB', 71]], dtype=object),
#  array([['Garry', 'Gilliam', 'Seahawks', 'LT', 72]], dtype=object),
#  array([['Bobby', 'Wagner', 'Seahawks', 'MLB', 88],
#         ['Brock', 'Coyle', 'Seahawks', 'MLB', 66]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Russell', 'Wilson', 'Seahawks', 'QB', 91]], dtype=object),
#  array([['Cliff', 'Avril', 'Seahawks', 'RE', 90]], dtype=object),
#  array([['Germain', 'Ifedi', 'Seahawks', 'RG', 75]], dtype=object),
#  array([['K.J.', 'Wright', 'Seahawks', 'ROLB', 88]], dtype=object),
#  array([['Bradley', 'Sowell', 'Seahawks', 'RT', 74]], dtype=object),
#  array([['Kam', 'Chancellor', 'Seahawks', 'SS', 91]], dtype=object),
#  array([['Jimmy', 'Graham', 'Seahawks', 'TE', 89]], dtype=object),
#  array([['Doug', 'Baldwin', 'Seahawks', 'WR', 89],
#         ['Jermaine', 'Kearse', 'Seahawks', 'WR', 80],
#         ['Tyler', 'Lockett', 'Seahawks', 'WR', 80]], dtype=object),
#  array([['Maurkice', 'Pouncey', 'Steelers', 'C', 88]], dtype=object),
#  array([['William', 'Gay', 'Steelers', 'CB', 82],
#         ['Ross', 'Cockrell', 'Steelers', 'CB', 73]], dtype=object),
#  array([['Ricardo', 'Mathews', 'Steelers', 'DT', 69],
#         ['Javon', 'Hargrave', 'Steelers', 'DT', 68]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Mike', 'Mitchell', 'Steelers', 'FS', 84]], dtype=object),
#  array([["Le'Veon", 'Bell', 'Steelers', 'HB', 94],
#         ['DeAngelo', 'Williams', 'Steelers', 'HB', 81]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Cameron', 'Heyward', 'Steelers', 'LE', 88]], dtype=object),
#  array([['Ramon', 'Foster', 'Steelers', 'LG', 82]], dtype=object),
#  array([['Arthur', 'Moats', 'Steelers', 'LOLB', 78]], dtype=object),
#  array([['Ryan', 'Harris', 'Steelers', 'LT', 76]], dtype=object),
#  array([['Ryan', 'Shazier', 'Steelers', 'MLB', 79],
#         ['Lawrence', 'Timmons', 'Steelers', 'MLB', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Ben', 'Roethlisberger', 'Steelers', 'QB', 93]], dtype=object),
#  array([['Stephon', 'Tuitt', 'Steelers', 'RE', 78]], dtype=object),
#  array([['David', 'DeCastro', 'Steelers', 'RG', 84]], dtype=object),
#  array([['James', 'Harrison', 'Steelers', 'ROLB', 85]], dtype=object),
#  array([['Marcus', 'Gilbert', 'Steelers', 'RT', 83]], dtype=object),
#  array([['Shamarko', 'Thomas', 'Steelers', 'SS', 72]], dtype=object),
#  array([['Ladarius', 'Green', 'Steelers', 'TE', 81]], dtype=object),
#  array([['Antonio', 'Brown', 'Steelers', 'WR', 97],
#         ['Martavis', 'Bryant', 'Steelers', 'WR', 82],
#         ['Markus', 'Wheaton', 'Steelers', 'WR', 76]], dtype=object),
#  array([['Nick', 'Martin', 'Texans', 'C', 73]], dtype=object),
#  array([['Johnathan', 'Joseph', 'Texans', 'CB', 91],
#         ['Kareem', 'Jackson', 'Texans', 'CB', 78]], dtype=object),
#  array([['Vince', 'Wilfork', 'Texans', 'DT', 84],
#         ['Devon', 'Still', 'Texans', 'DT', 67]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Antonio', 'Allen', 'Texans', 'FS', 79]], dtype=object),
#  array([['Lamar', 'Miller', 'Texans', 'HB', 88],
#         ['Alfred', 'Blue', 'Texans', 'HB', 76]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Brandon', 'Dunn', 'Texans', 'LE', 68]], dtype=object),
#  array([['Xavier', "Su'a-Filo", 'Texans', 'LG', 71]], dtype=object),
#  array([['Whitney', 'Mercilus', 'Texans', 'LOLB', 88]], dtype=object),
#  array([['Duane', 'Brown', 'Texans', 'LT', 86]], dtype=object),
#  array([['Brian', 'Cushing', 'Texans', 'MLB', 81],
#         ['Benardrick', 'McKinney', 'Texans', 'MLB', 77]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Brock', 'Osweiler', 'Texans', 'QB', 77]], dtype=object),
#  array([['J.J.', 'Watt', 'Texans', 'RE', 99]], dtype=object),
#  array([['Jeff', 'Allen', 'Texans', 'RG', 78]], dtype=object),
#  array([['Jadeveon', 'Clowney', 'Texans', 'ROLB', 83]], dtype=object),
#  array([['Derek', 'Newton', 'Texans', 'RT', 82]], dtype=object),
#  array([['Quintin', 'Demps', 'Texans', 'SS', 75]], dtype=object),
#  array([['C.J.', 'Fiedorowicz', 'Texans', 'TE', 77]], dtype=object),
#  array([['DeAndre', 'Hopkins', 'Texans', 'WR', 93],
#         ['Will', 'Fuller V', 'Texans', 'WR', 74],
#         ['Jaelen', 'Strong', 'Texans', 'WR', 73]], dtype=object),
#  array([['Ben', 'Jones', 'Titans', 'C', 74]], dtype=object),
#  array([['Jason', 'McCourty', 'Titans', 'CB', 80],
#         ['Brice', 'McCain', 'Titans', 'CB', 78]], dtype=object),
#  array([['Al', 'Woods', 'Titans', 'DT', 74],
#         ['Austin', 'Johnson', 'Titans', 'DT', 70]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Rashad', 'Johnson', 'Titans', 'FS', 82]], dtype=object),
#  array([['DeMarco', 'Murray', 'Titans', 'HB', 83],
#         ['Antonio', 'Andrews', 'Titans', 'HB', 76]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['DaQuan', 'Jones', 'Titans', 'LE', 68]], dtype=object),
#  array([['Byron', 'Bell', 'Titans', 'LG', 70]], dtype=object),
#  array([['Derrick', 'Morgan', 'Titans', 'LOLB', 81]], dtype=object),
#  array([['Taylor', 'Lewan', 'Titans', 'LT', 83]], dtype=object),
#  array([['Wesley', 'Woodyard', 'Titans', 'MLB', 87],
#         ['Avery', 'Williamson', 'Titans', 'MLB', 78]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Marcus', 'Mariota', 'Titans', 'QB', 79]], dtype=object),
#  array([['Jurrell', 'Casey', 'Titans', 'RE', 93]], dtype=object),
#  array([['Chance', 'Warmack', 'Titans', 'RG', 75]], dtype=object),
#  array([['Brian', 'Orakpo', 'Titans', 'ROLB', 87]], dtype=object),
#  array([['Jack', 'Conklin', 'Titans', 'RT', 79]], dtype=object),
#  array([["Da'Norris", 'Searcy', 'Titans', 'SS', 85]], dtype=object),
#  array([['Delanie', 'Walker', 'Titans', 'TE', 93]], dtype=object),
#  array([['Kendall', 'Wright', 'Titans', 'WR', 79],
#         ['Rishard', 'Matthews', 'Titans', 'WR', 79],
#         ['Andre', 'Johnson', 'Titans', 'WR', 76]], dtype=object),
#  array([['John', 'Sullivan', 'Vikings', 'C', 86]], dtype=object),
#  array([['Terence', 'Newman', 'Vikings', 'CB', 80],
#         ['Xavier', 'Rhodes', 'Vikings', 'CB', 80]], dtype=object),
#  array([['Linval', 'Joseph', 'Vikings', 'DT', 89],
#         ['Sharrif', 'Floyd', 'Vikings', 'DT', 83]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Harrison', 'Smith', 'Vikings', 'FS', 94]], dtype=object),
#  array([['Adrian', 'Peterson', 'Vikings', 'HB', 91],
#         ['Jerick', 'McKinnon', 'Vikings', 'HB', 76]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Brian', 'Robison', 'Vikings', 'LE', 79]], dtype=object),
#  array([['Brandon', 'Fusco', 'Vikings', 'LG', 72]], dtype=object),
#  array([['Anthony', 'Barr', 'Vikings', 'LOLB', 88]], dtype=object),
#  array([['Matt', 'Kalil', 'Vikings', 'LT', 80]], dtype=object),
#  array([['Eric', 'Kendricks', 'Vikings', 'MLB', 76],
#         ['Audie', 'Cole', 'Vikings', 'MLB', 67]], dtype=object),
#  array([], shape=(0, 5), dtype=object),
#  array([['Teddy', 'Bridgewater', 'Vikings', 'QB', 81]], dtype=object),
#  array([['Everson', 'Griffen', 'Vikings', 'RE', 88]], dtype=object),
#  array([['Alex', 'Boone', 'Vikings', 'RG', 81]], dtype=object),
#  array([['Chad', 'Greenway', 'Vikings', 'ROLB', 78]], dtype=object),
#  array([['Andre', 'Smith', 'Vikings', 'RT', 77]], dtype=object),
#  array([['Andrew', 'Sendejo', 'Vikings', 'SS', 78]], dtype=object),
#  array([['Kyle', 'Rudolph', 'Vikings', 'TE', 81]], dtype=object),
#  array([['Stefon', 'Diggs', 'Vikings', 'WR', 79],
#         ['Laquon', 'Treadwell', 'Vikings', 'WR', 75],
#         ['Jarius', 'Wright', 'Vikings', 'WR', 75]], dtype=object)]
